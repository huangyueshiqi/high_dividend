# %%
import cx_Oracle
import itertools
import joblib
import shap
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# import missingno as msno

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import  accuracy_score,roc_auc_score,average_precision_score,f1_score,precision_score,recall_score,classification_report,confusion_matrix
from xgboost import XGBClassifier
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter
from functools import  reduce
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 from sklearn.ensemble import VotingClassifier
#       2 from sklearn.metrics import  accuracy_score,roc_auc_score,average_precision_score,f1_score,precision_score,recall_score,classification_report,confusion_matrix
# ----> 3 from xgboost import XGBClassifier
#       4 from imblearn.under_sampling import RandomUnderSampler
#       5 from collections import Counter
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
# %matplotlib inline
sns.set_style('whitegrid')
from matplotlib import font_manager
font_path='/usr/share/fonts/cjkuni-uming/uming.ttc'
matplotlib.rcParams['font.family']=font_manager.FontProperties(fname=font_path).get_name()
matplotlib.rcParams['axes.unicode_minus']=False

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

# %%
#读取基金名称和月份数据，合并并清理空值，将每行的基金名称和其对应的非空月份分别存入两个列表
def clean_and_split_months(fund_names_path,months_path):
    #读取数据
    months_df=pd.read_csv(fund_names_path)
    fund_names_df=pd.read_csv(months_path)
    #合并数据框
    months_with_fund=pd.concat([fund_names_df,months_df],axis=1)
    #清理空值并将每一行的非空值提取为列表
    result_cleaned = months_with_fund.apply(lambda row: row.dropna().tolist(), axis=1)
    #分离基金名称和其对应的非空月份
    res = []
    for x in result_cleaned:
        if len(x) > 1:   #确保至少有基金名称和至少一个月份
            res.append(x)
    fund_names = [sublist[0] for sublist in res]
    months_list = [sublist[1:] for sublist in res]

    return fund_names,months_list

# %%
#相关股票数据信息读取与处理
fund_names_path='data/fund/eda/months_df.csv'
months_path='data/fund/eda/fund_names_df.csv'
fund_names,months_list=clean_and_split_months(fund_names_path,months_path)

# %%
#DP的SHAP值小于0.1且正样本过少：004098.OF({0: 8701, 1: 3}),563180.OF({0: 4362, 1: 10}),007178.OF({0: 2974, 1: 2}),007216.OF({0: 2974, 1: 2})，015290.OF({0: 12878, 1: 19})，015289.OF({0: 12878, 1: 19})
remove_list=['004098.OF','563180.OF','007178.OF','007216.OF','015290.OF','015289.OF']
fund_names=[item for item in fund_names if item not in remove_list]

# %%
months_list
# Out:
# [[201906.0,
#   201912.0,
#   202006.0,
#   202012.0,
#   202106.0,
#   202112.0,
#   202206.0,
#   202212.0],
#  [201712.0,
#   201806.0,
#   201812.0,
#   201906.0,
#   201912.0,
#   202006.0,
#   202012.0,
#   202106.0,
#   202112.0,
#   202206.0,
#   202212.0,
#   202306.0,
#   202312.0,
#   202406.0],
#  [202312.0, 202406.0],
#  [202306.0, 202312.0, 202406.0],
#  [201912.0,
#   202006.0,
#   202012.0,
#   202106.0,
#   202112.0,
#   202206.0,
#   202212.0,
#   202306.0,
#   202312.0,
#   202406.0],
#  [201712.0,
#   201806.0,
#   201812.0,
#   201906.0,
#   201912.0,
#   202006.0,
#   202012.0,
#   202106.0,
#   202112.0,
#   202206.0,
#   202212.0,
#   202306.0,
#   202312.0,
#   202406.0],
#  [202006.0,
#   202012.0,
#   202106.0,
#   202112.0,
#   202206.0,
#   202212.0,
#   202306.0,
#   202312.0,
#   202406.0],
#  [202012.0,
#   202106.0,
#   202112.0,
#   202206.0,
#   202212.0,
#   202306.0,
#   202312.0,
#   202406.0],
#  [201806.0,
#   201812.0,
#   201906.0,
#   201912.0,
#   202006.0,
#   202012.0,
#   202106.0,
#   202112.0,
#   202206.0,
#   202212.0,
#   202306.0,
#   202312.0,
#   202406.0],
#  [201903.0,
#   201906.0,
#   201912.0,
#   202006.0,
#   202012.0,
#   202106.0,
#   202112.0,
#   202206.0,
#   202212.0],
#  [202405.0],
#  [202012.0,
#   202106.0,
#   202112.0,
#   202206.0,
#   202212.0,
#   202306.0,
#   202312.0,
#   202406.0],
#  [202005.0, 202006.0, 202012.0, 202106.0],
#  [202006.0,
#   202012.0,
#   202106.0,
#   202112.0,
#   202206.0,
#   202212.0,
#   202306.0,
#   202312.0,
#   202406.0],
#  [202006.0,
#   202012.0,
#   202106.0,
#   202112.0,
#   202206.0,
#   202212.0,
#   202306.0,
#   202312.0,
#   202406.0],
#  [201712.0,
#   201806.0,
#   201812.0,
#   201906.0,
#   201912.0,
#   202006.0,
#   202012.0,
#   202106.0,
#   202112.0,
#   202206.0,
#   202212.0,
#   202306.0,
#   202312.0,
#   202406.0],
#  [201806.0,
#   201812.0,
#   201906.0,
#   201912.0,
#   202006.0,
#   202012.0,
#   202106.0,
#   202112.0,
#   202206.0,
#   202212.0,
#   202306.0,
#   202312.0,
#   202406.0],
#  [202006.0],
#  [202306.0, 202312.0, 202406.0],
#  [201912.0,
#   202006.0,
#   202012.0,
#   202106.0,
#   202112.0,
#   202206.0,
#   202212.0,
#   202306.0,
#   202312.0,
#   202406.0],
#  [202012.0,
#   202106.0,
#   202112.0,
#   202206.0,
#   202212.0,
#   202306.0,
#   202312.0,
#   202406.0],
#  [201706.0, 201712.0, 201806.0, 201812.0, 201906.0, 201912.0, 202006.0],
#  [201506.0,
#   201512.0,
#   201606.0,
#   201612.0,
#   201706.0,
#   201712.0,
#   201806.0,
#   201812.0,
#   201906.0,
#   201912.0,
#   202006.0,
#   202012.0,
#   202106.0,
#   202112.0,
#   202206.0,
#   202212.0,
#   202306.0,
#   202312.0,
#   202406.0],
#  [202012.0,
#   202106.0,
#   202112.0,
#   202206.0,
#   202212.0,
#   202306.0,
#   202312.0,
#   202406.0],
#  [202006.0,
#   202012.0,
#   202106.0,
#   202112.0,
#   202206.0,
#   202212.0,
#   202306.0,
#   202312.0,
#   202406.0],
#  [202006.0],
#  [202006.0,
#   202012.0,
#   202106.0,
#   202112.0,
#   202206.0,
#   202212.0,
#   202306.0,
#   202312.0,
#   202406.0],
#  [202012.0,
#   202106.0,
#   202112.0,
#   202206.0,
#   202212.0,
#   202306.0,
#   202312.0,
#   202406.0]]

# %%
fund_name=fund_names[0]

# %%
#加载time_simple_eda.ipynb处理好的特征标签文件time_series_eda_202411.csv  2022-09---2024-11
#加载和合并数据
all_data=[] #存储所有月份的数据
for month in months_list[0]:
    month=int(month)
    df=pd.read_csv(f'data/fund/eda/{fund_name}_eda_{month}.csv')
    df['month']=month
    all_data.append(df)

# %%
data=pd.concat(all_data,ignore_index=True)
data.head()
# Out:
#    CJJG_CODE  CJJG_OP_YOY  CJJG_OP_TTM_YOY  CJJG_CP_YOY  CJJG_CP_TTM_YOY  \
# 0  300223.SZ    -0.183175         0.568975     0.338788         0.646706
# 1  300224.SZ    -0.887866        -2.192115    -0.272875        -0.065246
# 2  300225.SZ    -0.428100        -0.883635     0.122011        -0.172045
# 3  300226.SZ     0.634002         1.424176     0.340440         0.527161
# 4  300227.SZ    -0.105612         0.095374     0.194730         0.056757
#
#    CJJG_NP_YOY  CJJG_NP_TTM_YOY  CJJG_NPAT_YOY  CJJG_NPAT_TTM_YOY  \
# 0    -0.173678         0.752528      -0.173678           0.752528
# 1    -0.773569        -1.920483      -0.724391          -1.820968
# 2    -0.437275        -0.833687      -0.372695          -0.814189
# 3     0.695789         1.426339       0.580813           1.118643
# 4    -0.188035         0.026638      -0.202302          -0.011705
#
#    CJJG_DNP_YOY  ...  CJJG_VOL_60  CJJG_VOL_240  CJJG_RES_VOL_10  \
# 0      0.351957  ...     0.045127      0.031918         0.063357
# 1     -0.725652  ...     0.040825      0.030539         0.057236
# 2     -0.423236  ...     0.039013      0.042365         0.018812
# 3      0.884800  ...     0.035698      0.033578         0.017136
# 4     -0.160551  ...     0.032074      0.026324         0.018866
#
#    CJJG_RES_VOL_20  CJJG_RES_VOL_60  CJJG_SR_10  CJJG_SR_20  CJJG_SR_60  \
# 0         0.055694         0.044593    0.023370    0.037427    0.006970
# 1         0.048217         0.035039    0.148840    0.241911    0.250883
# 2         0.018464         0.030911    0.242530    0.702322    0.361604
# 3         0.017722         0.029019    0.218411    0.681830    0.327994
# 4         0.015372         0.027496    0.020660    0.556336    0.252631
#
#    label   month
# 0      0  201906
# 1      0  201906
# 2      0  201906
# 3      0  201906
# 4      0  201906
#
# [5 rows x 168 columns]

# %%
#特征与标签,股票代码列分离
X=data.drop(columns=['CJJG_CODE','label','month'])

# %%
X.head()
# Out:
#    CJJG_OP_YOY  CJJG_OP_TTM_YOY  CJJG_CP_YOY  CJJG_CP_TTM_YOY  CJJG_NP_YOY  \
# 0    -0.183175         0.568975     0.338788         0.646706    -0.173678
# 1    -0.887866        -2.192115    -0.272875        -0.065246    -0.773569
# 2    -0.428100        -0.883635     0.122011        -0.172045    -0.437275
# 3     0.634002         1.424176     0.340440         0.527161     0.695789
# 4    -0.105612         0.095374     0.194730         0.056757    -0.188035
#
#    CJJG_NP_TTM_YOY  CJJG_NPAT_YOY  CJJG_NPAT_TTM_YOY  CJJG_DNP_YOY  \
# 0         0.752528      -0.173678           0.752528      0.351957
# 1        -1.920483      -0.724391          -1.820968     -0.725652
# 2        -0.833687      -0.372695          -0.814189     -0.423236
# 3         1.426339       0.580813           1.118643      0.884800
# 4         0.026638      -0.202302          -0.011705     -0.160551
#
#    CJJG_DNP_TTM_YOY  ...  CJJG_VOL_10  CJJG_VOL_20  CJJG_VOL_60  CJJG_VOL_240  \
# 0          0.096201  ...     0.067578     0.058241     0.045127      0.031918
# 1        -15.379107  ...     0.065394     0.056817     0.040825      0.030539
# 2         -0.933103  ...     0.022783     0.034721     0.039013      0.042365
# 3          0.984020  ...     0.020432     0.032234     0.035698      0.033578
# 4         -0.084714  ...     0.020095     0.023678     0.032074      0.026324
#
#    CJJG_RES_VOL_10  CJJG_RES_VOL_20  CJJG_RES_VOL_60  CJJG_SR_10  CJJG_SR_20  \
# 0         0.063357         0.055694         0.044593    0.023370    0.037427
# 1         0.057236         0.048217         0.035039    0.148840    0.241911
# 2         0.018812         0.018464         0.030911    0.242530    0.702322
# 3         0.017136         0.017722         0.029019    0.218411    0.681830
# 4         0.018866         0.015372         0.027496    0.020660    0.556336
#
#    CJJG_SR_60
# 0    0.006970
# 1    0.250883
# 2    0.361604
# 3    0.327994
# 4    0.252631
#
# [5 rows x 165 columns]

# %%
print(X.shape)
# Out:
# (26954, 165)

# %% [markdown]
# #### 处理共线性问题

# %%
#计算相关系数
#Pearson相关系数，用于衡量两个连续变量之间的线性相关性
correlation_matrix=X.corr()

#二维矩阵变为一维的MultIndex Series，索引为矩阵中原始的行和列，值为对应的相关性数值
high_corr=correlation_matrix[correlation_matrix>0.9].stack()
#通过重置索引来补齐索引，通过reset_index()将MultIndex转换为DataFrame
high_corr_reset=high_corr.reset_index()
high_corr_reset.columns=['features1','features2','correlation']
#去掉重复对和features1==features2的对
high_corr_cleaned=high_corr_reset[high_corr_reset['features1']<high_corr_reset['features2']].reset_index(drop=True)

# %%
#替换特征名字，如果找不到映射，使用原名字
mapping_features1=[mapping_dict.get(feature) for feature in high_corr_cleaned['features1']]
mapping_features2=[mapping_dict.get(feature) for feature in high_corr_cleaned['features2']]

# %%
high_corr_cleaned['mapping_features1']=mapping_features1
high_corr_cleaned['mapping_features2']=mapping_features2

# %%
high_corr_cleaned
# Out:
#             features1             features2  correlation mapping_features1  \
# 0     CJJG_CP_TTM_YOY           CJJG_CP_YOY     0.977487       主营利润_TTM_同比
# 1       CJJG_EBIT_YOY       CJJG_NOPLAT_YOY     1.000000           EBIT_同比
# 2   CJJG_EBIT_TTM_YOY   CJJG_NOPLAT_TTM_YOY     1.000000       EBIT_TTM_同比
# 3            CJJG_NPM              CJJG_POE     0.981719              净利润率
# 4            CJJG_GPM              CJJG_NPM     0.998673             销售毛利率
# ..                ...                   ...          ...               ...
# 94   CJJG_SALES2EV_12  CJJG_SALES2EV_12_TTM     0.980751       SALES2EV_12
# 95         CJJG_TR_10            CJJG_TR_20     0.947504            换手率_10
# 96    CJJG_RES_VOL_10           CJJG_VOL_10     0.977308          残差波动率_10
# 97    CJJG_RES_VOL_20           CJJG_VOL_20     0.966053          残差波动率_20
# 98    CJJG_RES_VOL_60           CJJG_VOL_60     0.970989          残差波动率_60
#
#    mapping_features2
# 0            主营利润_同比
# 1          NOPLAT_同比
# 2      NOPLAT_TTM_同比
# 3             三项费用比例
# 4               净利润率
# ..               ...
# 94   SALES2EV_12_TTM
# 95            换手率_20
# 96            波动率_10
# 97            波动率_20
# 98            波动率_60
#
# [99 rows x 5 columns]

# %%
correlation_matrix['CJJG_KU_240'].sort_values(ascending=False)
# Out:
# CJJG_KU_240        1.000000
# CJJG_KU_60         0.438979
# CJJG_KU_20         0.223323
# CJJG_RES_VOL_20    0.175691
# CJJG_VOL_240       0.168081
#                      ...
# CJJG_MOM_240      -0.246539
# CJJG_SK_60        -0.256324
# CJJG_MDR_20       -0.256482
# CJJG_MDR_60       -0.332615
# CJJG_SK_240       -0.853301
# Name: CJJG_KU_240, Length: 165, dtype: float64

# %%
high_corr_cleaned1
# Out:
#              features1        features2  correlation
# 13         CJJG_NP_YOY      CJJG_OP_YOY     0.963248
# 18     CJJG_NP_TTM_YOY  CJJG_OP_TTM_YOY     0.964671
# 24       CJJG_NPAT_YOY      CJJG_OP_YOY     0.946324
# 25       CJJG_NPAT_YOY      CJJG_NP_YOY     0.977737
# 29   CJJG_NPAT_TTM_YOY  CJJG_OP_TTM_YOY     0.951253
# ..                 ...              ...          ...
# 417         CJJG_TR_20       CJJG_TR_60     0.919144
# 457    CJJG_RES_VOL_10      CJJG_VOL_10     0.951588
# 459    CJJG_RES_VOL_20          CJJG_RV     0.934944
# 460    CJJG_RES_VOL_20      CJJG_VOL_20     0.932992
# 462    CJJG_RES_VOL_60      CJJG_VOL_60     0.956807
#
# [151 rows x 3 columns]

# %%
drop_columns=['CJJG_DP','CJJG_EBIT2EV','CJJG_CP_YOY','CJJG_PORE','CJJG_EBITDA2EV','CJJG_NOPLAT2EV','CJJG_SALES2EV','CJJG_TR_10','CJJG_TR_20','CJJG_MBPM','CJJG_POE','CJJG_DIO','CJJG_DSO','CJJG_ILQ_10','CJJG_ILQ_20']
# Out:
# ['CJJG_CP_TTM_YOY', 'CJJG_EBIT_YOY', 'CJJG_EBIT_TTM_YOY', 'CJJG_NPM', 'CJJG_GPM', 'CJJG_GPM', 'CJJG_GPM_TTM', 'CJJG_ATPROE', 'CJJG_ATPROE', 'CJJG_ATPROE_TTM', 'CJJG_ENIROE', 'CJJG_ENIROA', 'CJJG_ENIROA_TTM', 'CJJG_ARR', 'CJJG_ARR', 'CJJG_ARR_TTM', 'CJJG_ARR_TTM', 'CJJG_PORE', 'CJJG_EBIT2BI', 'CJJG_EBIT2BI', 'CJJG_EBIT2BI', 'CJJG_EBIT2BI', 'CJJG_EBIT2BI', 'CJJG_EBIT2BI_TTM', 'CJJG_EBIT2BI_TTM', 'CJJG_EBIT2BI_TTM', 'CJJG_EBITDA2BI', 'CJJG_EBITDA2BI', 'CJJG_EBITDA2BI', 'CJJG_EBITDA2BI', 'CJJG_EBITDA2BI_TTM', 'CJJG_EBITDA2BI_TTM', 'CJJG_ALR', 'CJJG_CR', 'CJJG_DSO', 'CJJG_DSO', 'CJJG_DSO', 'CJJG_DSO', 'CJJG_DSO', 'CJJG_DSO', 'CJJG_DSO', 'CJJG_DSO_TTM', 'CJJG_DTAT', 'CJJG_DTAT', 'CJJG_DTAT', 'CJJG_DTAT', 'CJJG_DTAT', 'CJJG_DTAT', 'CJJG_DTAT_TTM', 'CJJG_FATD', 'CJJG_FATD', 'CJJG_FATD', 'CJJG_FATD_TTM', 'CJJG_CORR', 'CJJG_CORR', 'CJJG_CORR', 'CJJG_CORR', 'CJJG_CORR', 'CJJG_CORR', 'CJJG_CORR', 'CJJG_CORR', 'CJJG_CORR_TTM', 'CJJG_CORR_TTM', 'CJJG_CORR_TTM', 'CJJG_CORR_TTM', 'CJJG_CCLR', 'CJJG_CCLR_TTM', 'CJJG_PS_TTM', 'CJJG_DP', 'CJJG_EBIT2EV', 'CJJG_EBIT2EV', 'CJJG_EBIT2EV', 'CJJG_EBIT2EV', 'CJJG_EBIT2EV', 'CJJG_EBIT2EV', 'CJJG_EBIT2EV_TTM', 'CJJG_EBIT2EV_TTM', 'CJJG_EBIT2EV_TTM', 'CJJG_EBIT2EV_TTM', 'CJJG_EBIT2EV_TTM', 'CJJG_EBITDA2EV', 'CJJG_EBITDA2EV', 'CJJG_EBITDA2EV', 'CJJG_EBITDA2EV', 'CJJG_EBITDA2EV_TTM', 'CJJG_EBITDA2EV_TTM', 'CJJG_EBITDA2EV_TTM', 'CJJG_NOPLAT2EV', 'CJJG_SALES2EV', 'CJJG_IC2EV', 'CJJG_IC2EV', 'CJJG_EBIT2EV_12', 'CJJG_EBIT2EV_12', 'CJJG_EBIT2EV_12', 'CJJG_EBIT2EV_12', 'CJJG_EBIT2EV_12', 'CJJG_EBIT2EV_12', 'CJJG_EBIT2EV_12_TTM', 'CJJG_EBIT2EV_12_TTM', 'CJJG_EBIT2EV_12_TTM', 'CJJG_EBITDA2EV_12', 'CJJG_EBITDA2EV_12_TTM', 'CJJG_EBITDA2EV_12_TTM', 'CJJG_NOPLAT2EV_12', 'CJJG_SALES2EV_12', 'CJJG_IC2EV_12', 'CJJG_TR_10', 'CJJG_RES_VOL_10', 'CJJG_RES_VOL_20', 'CJJG_RES_VOL_60']

# %%
drop_columns = ['CJJG_DP', 'CJJG_EBIT2EV', 'CJJG_CP_YOY', 'CJJG_PORE', 'CJJG_EBITDA2EV', 'CJJG_NOPLAT2EV',
                         'CJJG_SALES2EV', 'CJJG_TR_10', 'CJJG_TR_20', 'CJJG_MBPM', 'CJJG_POE', 'CJJG_DIO', 'CJJG_DSO',
                         'CJJG_ILQ_10', 'CJJG_ILQ_20']
X = X.drop(columns=['CJJG_DP'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[189], line 4
#       1 drop_columns = ['CJJG_DP', 'CJJG_EBIT2EV', 'CJJG_CP_YOY', 'CJJG_PORE', 'CJJG_EBITDA2EV', 'CJJG_NOPLAT2EV',
#       2                          'CJJG_SALES2EV', 'CJJG_TR_10', 'CJJG_TR_20', 'CJJG_MBPM', 'CJJG_POE', 'CJJG_DIO', 'CJJG_DSO',
#       3                          'CJJG_ILQ_10', 'CJJG_ILQ_20']
# ----> 4 X = X.drop(columns=['CJJG_DP', 'CJJG_EBIT2EV', 'CJJG_CP_YOY', 'CJJG_PORE', 'CJJG_EBITDA2EV', 'CJJG_NOPLAT2EV',
#       5                          'CJJG_SALES2EV', 'CJJG_TR_10', 'CJJG_TR_20', 'CJJG_MBPM', 'CJJG_POE', 'CJJG_DIO', 'CJJG_DSO',
#       6                          'CJJG_ILQ_10', 'CJJG_ILQ_20'])
#
# File ~/anaconda3/envs/zcenv/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/zcenv/lib/python3.8/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~/anaconda3/envs/zcenv/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/zcenv/lib/python3.8/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~/anaconda3/envs/zcenv/lib/python3.8/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~/anaconda3/envs/zcenv/lib/python3.8/site-packages/pandas/core/indexes/base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['CJJG_DP', 'CJJG_EBIT2EV', 'CJJG_CP_YOY', 'CJJG_PORE', 'CJJG_EBITDA2EV', 'CJJG_NOPLAT2EV', 'CJJG_SALES2EV', 'CJJG_TR_10', 'CJJG_TR_20', 'CJJG_MBPM', 'CJJG_POE', 'CJJG_DIO', 'CJJG_DSO', 'CJJG_ILQ_10', 'CJJG_ILQ_20'] not found in axis"

# %%
X
# Out:
#        CJJG_CODE  CJJG_OP_YOY  CJJG_OP_TTM_YOY  CJJG_CP_TTM_YOY  CJJG_NP_YOY  \
# 0      300223.SZ    -0.183175         0.568975         0.646706    -0.173678
# 1      300224.SZ    -0.887866        -2.192115        -0.065246    -0.773569
# 2      300225.SZ    -0.428100        -0.883635        -0.172045    -0.437275
# 3      300226.SZ     0.634002         1.424176         0.527161     0.695789
# 4      300227.SZ    -0.105612         0.095374         0.056757    -0.188035
# ...          ...          ...              ...              ...          ...
# 26949  001298.SZ          NaN              NaN              NaN          NaN
# 26950  001299.SZ          NaN              NaN              NaN          NaN
# 26951  001300.SZ          NaN              NaN              NaN          NaN
# 26952  001322.SZ          NaN              NaN              NaN          NaN
# 26953  001338.SZ          NaN              NaN              NaN          NaN
#
#        CJJG_NP_TTM_YOY  CJJG_NPAT_YOY  CJJG_NPAT_TTM_YOY  CJJG_DNP_YOY  \
# 0             0.752528      -0.173678           0.752528      0.351957
# 1            -1.920483      -0.724391          -1.820968     -0.725652
# 2            -0.833687      -0.372695          -0.814189     -0.423236
# 3             1.426339       0.580813           1.118643      0.884800
# 4             0.026638      -0.202302          -0.011705     -0.160551
# ...                ...            ...                ...           ...
# 26949              NaN            NaN                NaN           NaN
# 26950              NaN            NaN                NaN           NaN
# 26951              NaN            NaN                NaN           NaN
# 26952              NaN            NaN                NaN           NaN
# 26953              NaN            NaN                NaN           NaN
#
#        CJJG_DNP_TTM_YOY  ...  CJJG_VOL_60  CJJG_VOL_240  CJJG_RES_VOL_10  \
# 0              0.096201  ...     0.045127      0.031918         0.063357
# 1            -15.379107  ...     0.040825      0.030539         0.057236
# 2             -0.933103  ...     0.039013      0.042365         0.018812
# 3              0.984020  ...     0.035698      0.033578         0.017136
# 4             -0.084714  ...     0.032074      0.026324         0.018866
# ...                 ...  ...          ...           ...              ...
# 26949               NaN  ...          NaN           NaN         0.018652
# 26950               NaN  ...          NaN           NaN         0.050063
# 26951               NaN  ...          NaN           NaN         0.017075
# 26952               NaN  ...          NaN           NaN         0.031954
# 26953               NaN  ...          NaN           NaN         0.050200
#
#        CJJG_RES_VOL_20  CJJG_RES_VOL_60  CJJG_SR_10  CJJG_SR_20  CJJG_SR_60  \
# 0             0.055694         0.044593    0.023370    0.037427    0.006970
# 1             0.048217         0.035039    0.148840    0.241911    0.250883
# 2             0.018464         0.030911    0.242530    0.702322    0.361604
# 3             0.017722         0.029019    0.218411    0.681830    0.327994
# 4             0.015372         0.027496    0.020660    0.556336    0.252631
# ...                ...              ...         ...         ...         ...
# 26949         0.025403         0.034628    0.144759    0.085408    0.235737
# 26950         0.054929         0.058186    0.012097    0.060462    0.001890
# 26951         0.037129         0.058282    0.467671    0.003465    0.051284
# 26952         0.033150         0.037631    0.394997    0.160224    0.269741
# 26953         0.050200         0.050200    0.128397    0.128397    0.128397
#
#        label   month
# 0          0  201906
# 1          0  201906
# 2          0  201906
# 3          0  201906
# 4          0  201906
# ...      ...     ...
# 26949      0  202212
# 26950      0  202212
# 26951      0  202212
# 26952      0  202212
# 26953      0  202212
#
# [26954 rows x 153 columns]

# %%
#计算斯皮尔曼相关系数，衡量两个变量之间的等级关系的强度和方向，不要求变量之间的关系是线性的
correlation_matrix1=X.corr(method='spearman')

# %%
#二维矩阵变为一维的MultIndex Series，索引为矩阵中原始的行和列，值为对应的相关性数值
high_corr1=correlation_matrix1[correlation_matrix1>0.9].stack()
#通过重置索引来补齐索引，通过reset_index()将MultIndex转换为DataFrame
high_corr_reset1=high_corr1.reset_index()
high_corr_reset1.columns=['features1','features2','correlation']
#去掉重复对和features1==features2的对
high_corr_cleaned1=high_corr_reset1[high_corr_reset1['features1']<high_corr_reset1['features2']]

# %%
high_corr_cleaned1
# Out:
#              features1        features2  correlation
# 13         CJJG_NP_YOY      CJJG_OP_YOY     0.963248
# 18     CJJG_NP_TTM_YOY  CJJG_OP_TTM_YOY     0.964671
# 24       CJJG_NPAT_YOY      CJJG_OP_YOY     0.946324
# 25       CJJG_NPAT_YOY      CJJG_NP_YOY     0.977737
# 29   CJJG_NPAT_TTM_YOY  CJJG_OP_TTM_YOY     0.951253
# ..                 ...              ...          ...
# 417         CJJG_TR_20       CJJG_TR_60     0.919144
# 457    CJJG_RES_VOL_10      CJJG_VOL_10     0.951588
# 459    CJJG_RES_VOL_20          CJJG_RV     0.934944
# 460    CJJG_RES_VOL_20      CJJG_VOL_20     0.932992
# 462    CJJG_RES_VOL_60      CJJG_VOL_60     0.956807
#
# [151 rows x 3 columns]

# %%
correlation_matrix1['CJJG_REV_10'].sort_values(ascending=False)
# Out:
# CJJG_REV_10     1.000000
# CJJG_REV_20     0.608683
# CJJG_MCI_10     0.607455
# CJJG_MDD_10     0.542065
# CJJG_MDD_20     0.522695
#                   ...
# CJJG_WC        -0.086740
# CJJG_SR_10     -0.096007
# CJJG_BETA_60   -0.117948
# CJJG_SR_20     -0.130638
# CJJG_BETA_20   -0.179414
# Name: CJJG_REV_10, Length: 165, dtype: float64

# %%
months
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[212], line 1
# ----> 1 months
#
# NameError: name 'months' is not defined

# %%
tmp=['2012-12','2014-12','2022-12','2024-12','2023-12','2024-01']
tmp
# Out:
# ['2012-12', '2014-12', '2022-12', '2024-12', '2023-12', '2024-01']

# %%
from datetime import datetime
#字段串转换为datetime对象
month_date=datetime.strptime(month,'%Y-%m')
#设定一个基准日期，2024年1月1日
comparison_date=datetime(2024,1,1)
#判断是否小于2024年
if month_date<comparison_date:
    print('yes')
else:
    print('no')
# Out:
# yes

# %%
#筛选24年以前的月份
filter_month=[month for month in tmp if datetime.strptime(month,'%Y-%m')<comparison_date]

# %%
filter_month
# Out:
# ['2012-12', '2014-12', '2022-12', '2023-12']

# %%
print(month_date)
# Out:
# 2022-12-01 00:00:00

# %%
y=data['label']

# %%
y.shape
# Out:
# (26954,)

# %%
y_code=data[['CJJG_CODE','label']]

# %%
y_code.head()
# Out:
#    CJJG_CODE  label
# 0  300223.SZ      0
# 1  300224.SZ      0
# 2  300225.SZ      0
# 3  300226.SZ      0
# 4  300227.SZ      0

# %%
#模型评估指标函数，打印Recall和F1
def metric_score(test_y,pre_y):
    #模型评估
    accuracy=accuracy_score(test_y,pre_y)
    auroc=roc_auc_score(test_y,pre_y)
    aupr=average_precision_score(test_y,pre_y)
    f1=f1_score(test_y,pre_y)
    precision=precision_score(test_y,pre_y)
    recall=recall_score(test_y,pre_y)
    
    #分类报告
    report=classification_report(test_y,pre_y)
    
    # print(report)
    print("Recall:%.3f"% recall)
    print("Precision:%.3f"% precision)
    print("F1:%.3f"% f1)

# %%
def plot_confusion_matrix(cm,classes,fund_name,cmap=plt.cm.Blues):
    plt.imshow(cm,interpolation='nearest',cmap=cmap)
    plt.title(f'{fund_name}_confusion_matrix')
    plt.colorbar()
    tick_marks=np.arange(len(classes))
    plt.xticks(tick_marks,classes)
    plt.yticks(tick_marks,classes)
    
    thresh=cm.max()/2
    for i,j in itertools.product(range(cm.shape[0]),range(cm.shape[1])):
        plt.text(j,i,cm[i,j],horizontalalignment='center',color='white' if cm[i,j]>thresh else 'black')
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predict label')
    plt.savefig(f'data/fund/fig/{fund_name}_confusion_matrix.svg')

# %%
stockcode_name=pd.read_csv('data/stockcode_name.csv')
stockcode_name
# Out:
#       STOCKCODE      SESNAME
# 0     837758.BJ  宏天信业(IPO终止)
# 1     300508.SZ         维宏股份
# 2     300551.SZ         古鳌科技
# 3     002835.SZ         同为股份
# 4     002601.SZ         龙佰集团
# ...         ...          ...
# 5832  688819.SH         天能股份
# 5833  300935.SZ          盈建科
# 5834  003042.SZ         中农联合
# 5835  301235.SZ         华康医疗
# 5836  688283.SH         坤恒顺维
#
# [5837 rows x 2 columns]

# %%
#加载因子名字文件
factor_name=pd.read_csv('data/factor_name.csv')
factor_name
# Out:
#           COLUMNAME   FACTORNAME
# 0       cjjg_smv_63      聪明钱v_63
# 1       cjjg_smr_21     聪明钱排序_21
# 2       cjjg_smr_63     聪明钱排序_63
# 3     CJJG_STM_5_10    短期动量_5_10
# 4    CJJG_STER_5_10  短期加强反转_5_10
# ..              ...          ...
# 554   CJJG_CFAPM_20    集合替APM_20
# 555   CJJG_COAPM_20     集合APM_20
# 556     CJJG_TPR_20      时量价比_20
# 557     CJJG_TPR_10      时量价比_10
# 558        CJJG_PTL         价格时滞
#
# [559 rows x 2 columns]

# %%
#统一因子字段为大写
factor_name['COLUMNAME']=factor_name['COLUMNAME'].str.upper()
#创建映射字典
mapping_dict=factor_name.set_index('COLUMNAME')['FACTORNAME'].to_dict()
mapping_dict
# Out:
# {'CJJG_SMV_63': '聪明钱v_63',
#  'CJJG_SMR_21': '聪明钱排序_21',
#  'CJJG_SMR_63': '聪明钱排序_63',
#  'CJJG_STM_5_10': '短期动量_5_10',
#  'CJJG_STER_5_10': '短期加强反转_5_10',
#  'CJJG_ESIEF': '高管增持事件因子',
#  'CJJG_NPEF': '负向业绩预告事件因子',
#  'CJJG_NPEEF': '负向业绩快报事件因子',
#  'CJJG_LUF': '涨停事件因子',
#  'CJJG_LREF': '领涨事件因子',
#  'CJJG_ESEF': '事件外溢效应因子',
#  'CJJG_ER_5_10': '极端收益_5_10',
#  'CJJG_DF_VP_TCN': '日频_量价_TCN',
#  'CJJG_M1_VP_TCN': '1分钟_量价_TCN',
#  'CJJG_DF_1M_VP_TCN': '日频_1分钟_量价_TCN',
#  'CJJG_ILLQ_240_20': '非流动性_240_20',
#  'CJJG_PATHILLQ_240_20': '路径非流动性_240_20',
#  'CJJG_TRAJILLQ_240_20': '轨迹非流动性_240_20',
#  'CJJG_REGILLQ_240_20': '回归非流动性_240_20',
#  'CJJG_UDILLQ_RATIO_240_20': '上下行非流动性比_240_20',
#  'CJJG_TPR_5_20': '时量价比_5_20',
#  'CJJG_HPA_5_20': '高价振幅_5_20',
#  'CJJG_LPA_5_20': '低价振幅_5_20',
#  'CJJG_HPTP_5_20': '高价成交占比_5_20',
#  'CJJG_LPTP_5_20': '低价成交占比_5_20',
#  'CJJG_VWR_5_20': '成交量加权反转_5_20',
#  'CJJG_HVTC_5_20': '高量交易成本_5_20',
#  'CJJG_HVPT_5_20': '高量每笔成交_5_20',
#  'CJJG_LVTC_5_20': '低量交易成本_5_20',
#  'CJJG_LVPT_5_20': '低量每笔成交_5_20',
#  'CJJG_HDTC_5_20': '高密度交易成本_5_20',
#  'CJJG_HDPT_5_20': '高密度每笔成交_5_20',
#  'CJJG_LDTC_5_20': '低密度交易成本_5_20',
#  'CJJG_LDPT_5_20': '低密度每笔成交_5_20',
#  'CJJG_STR_5_20': '短期反转_5_20',
#  'CJJG_STM_5_20': '短期动量_5_20',
#  'CJJG_STER_5_20': '短期加强反转_5_20',
#  'CJJG_ER_5_20': '极端收益_5_20',
#  'CJJG_PER_5_20': '极端前收益_5_20',
#  'CJJG_POER_5_20': '极端后收益_5_20',
#  'CJJG_LVR_5_20': '左端收益VaR_5_20',
#  'CJJG_RVR_5_20': '右端收益VaR_5_20',
#  'CJJG_LRPD_5_20': '左右概率差_5_20',
#  'CJJG_LVCVR_5_20': '左端收益CVaR_5_20',
#  'CJJG_UDVR_5_20': '右端收益CVaR_5_20',
#  'CJJG_UPDOWNVR_5_20': '上下行波动占比_5_20',
#  'CJJG_INFO_DISP_5_20': '信息离散度_5_20',
#  'CJJG_PVT_5_20': '量价相关性趋势_5_20',
#  'CJJG_TPR_5_10': '时量价比_5_10',
#  'CJJG_HPA_5_10': '高价振幅_5_10',
#  'CJJG_LPA_5_10': '低价振幅_5_10',
#  'CJJG_HPTP_5_10': '高价成交占比_5_10',
#  'CJJG_LPTP_5_10': '低价成交占比_5_10',
#  'CJJG_VWR_5_10': '成交量加权反转_5_10',
#  'CJJG_HVTC_5_10': '高量交易成本_5_10',
#  'CJJG_HVPT_5_10': '高量每笔成交_5_10',
#  'CJJG_LVTC_5_10': '低量交易成本_5_10',
#  'CJJG_LVPT_5_10': '低量每笔成交_5_10',
#  'CJJG_HDTC_5_10': '高密度交易成本_5_10',
#  'CJJG_HDPT_5_10': '高密度每笔成交_5_10',
#  'CJJG_LDTC_5_10': '低密度交易成本_5_10',
#  'CJJG_LDPT_5_10': '低密度每笔成交_5_10',
#  'CJJG_STR_5_10': '短期反转_5_10',
#  'CJJG_SR': '特异率',
#  'CJJG_RV': '残差波动率',
#  'CJJG_WC': '波峰',
#  'CJJG_CVP': '量价相关性',
#  'CJJG_WS': '加权偏度',
#  'CJJG_STR': '短期反转',
#  'CJJG_STM': '短期动量',
#  'CJJG_PFT': '盈利',
#  'CJJG_ANPG': '绝对净利润增长',
#  'CJJG_ARG': '绝对营收增长',
#  'CJJG_RNPG': '相对净利润增长',
#  'CJJG_RRG': '相对营收增长',
#  'CJJG_EG': '预期增长',
#  'CJJG_BTE': '超预期',
#  'CJJG_BI': '空头意愿',
#  'CJJG_ILQ': '非流动性',
#  'CJJG_OP_YOY': '营业利润_同比',
#  'CJJG_OP_TTM_YOY': '营业利润_TTM_同比',
#  'CJJG_CP_YOY': '主营利润_同比',
#  'CJJG_CP_TTM_YOY': '主营利润_TTM_同比',
#  'CJJG_NP_YOY': '净利润_同比',
#  'CJJG_NP_TTM_YOY': '净利润_TTM_同比',
#  'CJJG_NPAT_YOY': '归母净利润_同比',
#  'CJJG_NPAT_TTM_YOY': '归母净利润_TTM_同比',
#  'CJJG_DNP_YOY': '扣非净利润_同比',
#  'CJJG_DNP_TTM_YOY': '扣非净利润_TTM_同比',
#  'CJJG_OR_YOY': '营业收入_同比',
#  'CJJG_OR_TTM_YOY': '营业收入_TTM_同比',
#  'CJJG_EBIT_YOY': 'EBIT_同比',
#  'CJJG_EBIT_TTM_YOY': 'EBIT_TTM_同比',
#  'CJJG_EBITDA_YOY': 'EBITDA_同比',
#  'CJJG_EBITDA_TTM_YOY': 'EBITDA_TTM_同比',
#  'CJJG_NOPLAT_YOY': 'NOPLAT_同比',
#  'CJJG_NOPLAT_TTM_YOY': 'NOPLAT_TTM_同比',
#  'CJJG_NCFOA_YOY': '经营活动现金流净额_同比',
#  'CJJG_NCFOA_TTM_YOY': '经营活动现金流净额_TTM_同比',
#  'CJJG_NPM': '净利润率',
#  'CJJG_NPM_TTM': '净利润率_TTM',
#  'CJJG_GPM': '销售毛利率',
#  'CJJG_GPM_TTM': '销售毛利率_TTM',
#  'CJJG_MBPM': '主营业务利润率',
#  'CJJG_MBPM_TTM': '主营业务利润率_TTM',
#  'CJJG_ROE': 'ROE',
#  'CJJG_ROE_TTM': 'ROE_TTM',
#  'CJJG_ATPROE': '归母ROE',
#  'CJJG_ATPROE_TTM': '归母ROE_TTM',
#  'CJJG_ENIROE': '扣非ROE',
#  'CJJG_ENIROE_TTM': '扣非ROE_TTM',
#  'CJJG_ROA': 'ROA',
#  'CJJG_ROA_TTM': 'ROA_TTM',
#  'CJJG_ENIROA': '扣非ROA',
#  'CJJG_ENIROA_TTM': '扣非ROA_TTM',
#  'CJJG_ROC': '资本报酬率',
#  'CJJG_ROC_TTM': '资本报酬率_TTM',
#  'CJJG_ARR': '资产报酬率',
#  'CJJG_ARR_TTM': '资产报酬率_TTM',
#  'CJJG_POE': '三项费用比例',
#  'CJJG_POE_TTM': '三项费用比例_TTM',
#  'CJJG_PORE': '研发费用比例',
#  'CJJG_PORE_TTM': '研发费用比例_TTM',
#  'CJJG_EBIT2BI': 'EBIT2营业收入',
#  'CJJG_EBIT2BI_TTM': 'EBIT2营业收入_TTM',
#  'CJJG_EBITDA2BI': 'EBITDA2营业收入',
#  'CJJG_EBITDA2BI_TTM': 'EBITDA2营业收入_TTM',
#  'CJJG_ALR': '资产负债率',
#  'CJJG_ALR_AR': '资产负债率_扣预收',
#  'CJJG_LR': '杠杆率',
#  'CJJG_CR': '流动比率',
#  'CJJG_QR': '速动比率',
#  'CJJG_LTDR': '长期负债比率',
#  'CJJG_PCA': '流动资产比例',
#  'CJJG_PAR': '应收账款占比',
#  'CJJG_POG': '商誉占比',
#  'CJJG_DIO': '存货周转天数',
#  'CJJG_DIO_TTM': '存货周转天数_TTM',
#  'CJJG_DSO': '应收账款周转天数',
#  'CJJG_DSO_TTM': '应收账款周转天数_TTM',
#  'CJJG_DTAT': '总资产周转天数',
#  'CJJG_DTAT_TTM': '总资产周转天数_TTM',
#  'CJJG_FATD': '固定资产周转天数',
#  'CJJG_FATD_TTM': '固定资产周转天数_TTM',
#  'CJJG_CORR': '现金营业收入比率',
#  'CJJG_CORR_TTM': '现金营业收入比率_TTM',
#  'CJJG_CNPR': '现金净利润比率',
#  'CJJG_CNPR_TTM': '现金净利润比率_TTM',
#  'CJJG_CTAR': '现金总资产比率',
#  'CJJG_CTAR_TTM': '现金总资产比率_TTM',
#  'CJJG_CCLR': '现金流动负债比率',
#  'CJJG_CCLR_TTM': '现金流动负债比率_TTM',
#  'CJJG_CTLR': '现金总负债比率',
#  'CJJG_CTLR_TTM': '现金总负债比率_TTM',
#  'CJJG_NOPLAT2IC': 'NOPLAT2IC',
#  'CJJG_SP': 'SP',
#  'CJJG_PS_TTM': 'PS_TTM',
#  'CJJG_EP': 'EP',
#  'CJJG_EP_TTM': 'EP_TTM',
#  'CJJG_CF': 'CF',
#  'CJJG_CF_TTM': 'CF_TTM',
#  'CJJG_BP': 'BP',
#  'CJJG_DP_TTM': 'DP_TTM',
#  'CJJG_DP': 'DP',
#  'CJJG_EBIT2EV': 'EBIT2EV',
#  'CJJG_EBIT2EV_TTM': 'EBIT2EV_TTM',
#  'CJJG_EBITDA2EV': 'EBITDA2EV',
#  'CJJG_EBITDA2EV_TTM': 'EBITDA2EV_TTM',
#  'CJJG_NOPLAT2EV': 'NOPLAT2EV',
#  'CJJG_NOPLAT2EV_TTM': 'NOPLAT2EV_TTM',
#  'CJJG_SALES2EV': 'SALES2EV',
#  'CJJG_SALES2EV_TTM': 'SALES2EV_TTM',
#  'CJJG_IC2EV': 'IC2EV',
#  'CJJG_EBIT2EV_12': 'EBIT2EV_12',
#  'CJJG_EBIT2EV_12_TTM': 'EBIT2EV_12_TTM',
#  'CJJG_EBITDA2EV_12': 'EBITDA2EV_12',
#  'CJJG_EBITDA2EV_12_TTM': 'EBITDA2EV_12_TTM',
#  'CJJG_NOPLAT2EV_12': 'NOPLAT2EV_12',
#  'CJJG_NOPLAT2EV_12_TTM': 'NOPLAT2EV_12_TTM',
#  'CJJG_SALES2EV_12': 'SALES2EV_12',
#  'CJJG_SALES2EV_12_TTM': 'SALES2EV_12_TTM',
#  'CJJG_IC2EV_12': 'IC2EV_12',
#  'CJJG_NP_GRN': '净利润_明年增速',
#  'CJJG_EPS_GRN': '每股收益_明年增速',
#  'CJJG_OI_GRN': '营业收入_明年增速',
#  'CJJG_EBIT_GRN': 'EBIT_明年增速',
#  'CJJG_EBITDA_GRN': 'EBITDA_明年增速',
#  'CJJG_TP_GRN': '利润总额_明年增速',
#  'CJJG_OP_GRN': '营业利润_明年增速',
#  'CJJG_NP_GRAY': '净利润_后年增速',
#  'CJJG_EPS_GRAY': '每股收益_后年增速',
#  'CJJG_OI_GRAY': '营业收入_后年增速',
#  'CJJG_EBIT_GRAY': 'EBIT_后年增速',
#  'CJJG_EBITDA_GRAY': 'EBITDA_后年增速',
#  'CJJG_TP_GRAY': '利润总额_后年增速',
#  'CJJG_OP_GRAY': '营业利润_后年增速',
#  'CJJG_NP_CGR': '净利润_复合增速',
#  'CJJG_EPS_CGR': '每股收益_复合增速',
#  'CJJG_OI_CGR': '营业收入_复合增速',
#  'CJJG_EBIT_CGR': 'EBIT_复合增速',
#  'CJJG_EBITDA_CGR': 'EBITDA_复合增速',
#  'CJJG_TP_CGR': '利润总额_复合增速',
#  'CJJG_OP_CGR': '营业利润_复合增速',
#  'CJJG_ROE_GRN': 'ROE_明年增速',
#  'CJJG_ROE_GRAY': 'ROE_后年增速',
#  'CJJG_ROE_CGRYAN': 'ROE_后年复合增速',
#  'CJJG_PE_NY': 'PE_明年',
#  'CJJG_PB_NY': 'PB_明年',
#  'CJJG_PCF_NY': 'PCF_明年',
#  'CJJG_DP_NY': 'DP_明年',
#  'CJJG_PE_TYAN': 'PE_后年',
#  'CJJG_PB_TYAN': 'PB_后年',
#  'CJJG_PCF_TYAN': 'PCF_后年',
#  'CJJG_DP_TYAN': 'DP_后年',
#  'CJJG_PE_C': 'PE_复合',
#  'CJJG_PCF_C': 'PCF_复合',
#  'CJJG_PEG_NY': 'PEG_明年',
#  'CJJG_PEG_TYAN': 'PEG_后年',
#  'CJJG_PEG_C': 'PEG_复合',
#  'CJJG_CD_5': '覆盖度_5',
#  'CJJG_CD_4': '覆盖度_4',
#  'CJJG_CD_3': '覆盖度_3',
#  'CJJG_CD_2': '覆盖度_2',
#  'CJJG_TPG_4': '目标价差距_4',
#  'CJJG_TPG_3': '目标价差距_3',
#  'CJJG_TPG_2': '目标价差距_2',
#  'CJJG_LEE_5': '线性超预期_5',
#  'CJJG_GRE_5': '增速超预期_5',
#  'CJJG_LEE_4': '线性超预期_4',
#  'CJJG_GRE_4': '增速超预期_4',
#  'CJJG_LEE_3': '线性超预期_3',
#  'CJJG_GRE_3': '增速超预期_3',
#  'CJJG_LEE_2': '线性超预期_2',
#  'CJJG_GRE_2': '增速超预期_2',
#  'CJJG_ER_4': '预期评分_4',
#  'CJJG_ER_3': '预期评分_3',
#  'CJJG_ER_2': '预期评分_2',
#  'CJJG_ILQ_10': '非流动性_10',
#  'CJJG_ILQ_20': '非流动性_20',
#  'CJJG_ILQ_60': '非流动性_60',
#  'CJJG_TR_10': '换手率_10',
#  'CJJG_TR_20': '换手率_20',
#  'CJJG_TR_60': '换手率_60',
#  'CJJG_REV_10': '反转_10',
#  'CJJG_REV_20': '反转_20',
#  'CJJG_REV_60': '反转_60',
#  'CJJG_MOM_240': '动量_240',
#  'CJJG_SK_10': '偏度_10',
#  'CJJG_SK_20': '偏度_20',
#  'CJJG_SK_60': '偏度_60',
#  'CJJG_SK_240': '偏度_240',
#  'CJJG_KU_10': '峰度_10',
#  'CJJG_KU_20': '峰度_20',
#  'CJJG_KU_60': '峰度_60',
#  'CJJG_KU_240': '峰度_240',
#  'CJJG_MIR_10': '最大涨幅_10',
#  'CJJG_MIR_20': '最大涨幅_20',
#  'CJJG_MIR_60': '最大涨幅_60',
#  'CJJG_MDR_10': '最大跌幅_10',
#  'CJJG_MDR_20': '最大跌幅_20',
#  'CJJG_MDR_60': '最大跌幅_60',
#  'CJJG_MDD_10': '最大回撤_10',
#  'CJJG_MDD_20': '最大回撤_20',
#  'CJJG_MDD_60': '最大回撤_60',
#  'CJJG_MCI_10': '最大累计涨幅_10',
#  'CJJG_MCI_20': '最大累计涨幅_20',
#  'CJJG_MCI_60': '最大累计涨幅_60',
#  'CJJG_MA_10': '最大振幅_10',
#  'CJJG_MA_20': '最大振幅_20',
#  'CJJG_MA_60': '最大振幅_60',
#  'CJJG_BETA_10': 'Beta_10',
#  'CJJG_BETA_20': 'Beta_20',
#  'CJJG_BETA_60': 'Beta_60',
#  'CJJG_VOL_10': '波动率_10',
#  'CJJG_VOL_20': '波动率_20',
#  'CJJG_VOL_60': '波动率_60',
#  'CJJG_VOL_240': '波动率_240',
#  'CJJG_RES_VOL_10': '残差波动率_10',
#  'CJJG_RES_VOL_20': '残差波动率_20',
#  'CJJG_RES_VOL_60': '残差波动率_60',
#  'CJJG_SR_10': '特异率_10',
#  'CJJG_SR_20': '特异率_20',
#  'CJJG_SR_60': '特异率_60',
#  'CJJG_SM_21': '二阶矩_21',
#  'CJJG_SM_63': '二阶矩_63',
#  'CJJG_TM_21': '三阶矩_21',
#  'CJJG_TM_63': '三阶矩_63',
#  'CJJG_FM_21': '四阶矩_21',
#  'CJJG_FM_63': '四阶矩_63',
#  'CJJG_UV_21': '上行波动率_21',
#  'CJJG_UV_63': '上行波动率_63',
#  'CJJG_DV_21': '下行波动率_21',
#  'CJJG_DV_63': '下行波动率_63',
#  'CJJG_RV_21': '已实现波动率_21',
#  'CJJG_RV_63': '已实现波动率_63',
#  'CJJG_ANCPCR_21': '平均净委买变化率_21',
#  'CJJG_ANCPCR_63': '平均净委买变化率_63',
#  'CJJG_VNCPCR_21': '净委买变化率波动率_21',
#  'CJJG_VNCPCR_63': '净委买变化率波动率_63',
#  'CJJG_SNPCR_21': '净委买变化率偏度_21',
#  'CJJG_SNPCR_63': '净委买变化率偏度_63',
#  'CJJG_LONCIR_21': '大单资金净流入率_21',
#  'CJJG_LONCIR_63': '大单资金净流入率_63',
#  'CJJG_LONCIA_21': '大单资金净流入金额_21',
#  'CJJG_LONCIA_63': '大单资金净流入金额_63',
#  'CJJG_LODI_21': '大单驱动涨幅_21',
#  'CJJG_LODI_63': '大单驱动涨幅_63',
#  'CJJG_CIAO_21': '开盘累计涨幅_21',
#  'CJJG_CIAO_63': '开盘累计涨幅_63',
#  'CJJG_CICAT_21': '尾盘累计涨幅_21',
#  'CJJG_CICAT_63': '尾盘累计涨幅_63',
#  'CJJG_TI_21': '趋势强度_21',
#  'CJJG_TI_63': '趋势强度_63',
#  'CJJG_TWARPP_21': '时间加权平均的相对价格位置_21',
#  'CJJG_TWARPP_63': '时间加权平均的相对价格位置_63',
#  'CJJG_CVP_21': '量价相关性_21',
#  'CJJG_CVP_63': '量价相关性_63',
#  'CJJG_APD_21': '均价偏差_21',
#  'CJJG_APD_63': '均价偏差_63',
#  'CJJG_RASIOA_21': '平均单笔流入流出金额之比_21',
#  'CJJG_RASIOA_63': '平均单笔流入流出金额之比_63',
#  'CJJG_PSIAA_21': '平均单笔流入金额占比_21',
#  'CJJG_PSIAA_63': '平均单笔流入金额占比_63',
#  'CJJG_PSAOA_21': '平均单笔流出金额占比_21',
#  'CJJG_PSAOA_63': '平均单笔流出金额占比_63',
#  'CJJG_SMBETA_21': '聪明钱Beta_21',
#  'CJJG_SMBETA_63': '聪明钱Beta_63',
#  'CJJG_SMLN_21': '聪明钱Ln_21',
#  'CJJG_SMLN_63': '聪明钱Ln_63',
#  'CJJG_SMV_21': '聪明钱v_21',
#  'CJJG_PER_5_10': '极端前收益_5_10',
#  'CJJG_POER_5_10': '极端后收益_5_10',
#  'CJJG_LVR_5_10': '左端收益VaR_5_10',
#  'CJJG_RVR_5_10': '右端收益VaR_5_10',
#  'CJJG_LRPD_5_10': '左右概率差_5_10',
#  'CJJG_LVCVR_5_10': '左端收益CVaR_5_10',
#  'CJJG_UDVR_5_10': '右端收益CVaR_5_10',
#  'CJJG_UPDOWNVR_5_10': '上下行波动占比_5_10',
#  'CJJG_INFO_DISP_5_10': '信息离散度_5_10',
#  'CJJG_PVT_5_10': '量价相关性趋势_5_10',
#  'CJJG_PVT_1_20': '量价相关性趋势_1_20',
#  'CJJG_OPTP_5_20': '开盘成交占比_5_20',
#  'CJJG_OPTP_10_20': '开盘成交占比_10_20',
#  'CJJG_MPTP_5_20': '午盘成交占比_5_20',
#  'CJJG_MPTP_10_20': '午盘成交占比_10_20',
#  'CJJG_CPTP_5_20': '收盘成交占比_5_20',
#  'CJJG_CPTP_10_20': '收盘成交占比_10_20',
#  'CJJG_CR_1_20': '一致反转_1_20',
#  'CJJG_CP_1_20': '一致占比_1_20',
#  'CJJG_CPT_1_20': '一致每笔成交_1_20',
#  'CJJG_CPC_1_20': '一致成本_1_20',
#  'CJJG_CPBP_1_20': '一致买入占比_1_20',
#  'CJJG_HPA_1_20': '高价振幅_1_20',
#  'CJJG_LPA_1_20': '低价振幅_1_20',
#  'CJJG_HPTP_1_20': '高价成交占比_1_20',
#  'CJJG_LPTP_1_20': '低价成交占比_1_20',
#  'CJJG_VWR_1_20': '成交量加权反转_1_20',
#  'CJJG_HVTC_1_20': '高量交易成本_1_20',
#  'CJJG_HVPT_1_20': '高量每笔成交_1_20',
#  'CJJG_LVTC_1_20': '低量交易成本_1_20',
#  'CJJG_LVPT_1_20': '低量每笔成交_1_20',
#  'CJJG_HDTC_1_20': '高密度交易成本_1_20',
#  'CJJG_HDPT_1_20': '高密度每笔成交_1_20',
#  'CJJG_LDTC_1_20': '低密度交易成本_1_20',
#  'CJJG_LDPT_1_20': '低密度每笔成交_1_20',
#  'CJJG_MBP_1_20': '主买占比_1_20',
#  'CJJG_LSP_1_20': '量大单占比_1_20',
#  'CJJG_LSBP_1_20': '量大单买入占比_1_20',
#  'CJJG_STR_1_20': '短期反转_1_20',
#  'CJJG_STM_1_20': '短期动量_1_20',
#  'CJJG_STER_1_20': '短期加强反转_1_20',
#  'CJJG_ER_1_20': '极端收益_1_20',
#  'CJJG_PER_1_20': '极端前收益_1_20',
#  'CJJG_POER_1_20': '极端后收益_1_20',
#  'CJJG_LVR_1_20': '左端收益VaR_1_20',
#  'CJJG_RVR_1_20': '右端收益VaR_1_20',
#  'CJJG_LRPD_1_20': '左右概率差_1_20',
#  'CJJG_LVCVR_1_20': '左端收益CVaR_1_20',
#  'CJJG_UDVR_1_20': '右端收益CVaR_1_20',
#  'CJJG_UPDOWNVR_1_20': '上下行波动占比_1_20',
#  'CJJG_INFO_DISP_1_20': '信息离散度_1_20',
#  'CJJG_PVT_1_10': '量价相关性趋势_1_10',
#  'CJJG_OPTP_5_10': '开盘成交占比_5_10',
#  'CJJG_OPTP_10_10': '开盘成交占比_10_10',
#  'CJJG_MPTP_5_10': '午盘成交占比_5_10',
#  'CJJG_MPTP_10_10': '午盘成交占比_10_10',
#  'CJJG_CPTP_5_10': '收盘成交占比_5_10',
#  'CJJG_CPTP_10_10': '收盘成交占比_10_10',
#  'CJJG_CR_1_10': '一致反转_1_10',
#  'CJJG_CP_1_10': '一致占比_1_10',
#  'CJJG_CPT_1_10': '一致每笔成交_1_10',
#  'CJJG_CPC_1_10': '一致成本_1_10',
#  'CJJG_CPBP_1_10': '一致买入占比_1_10',
#  'CJJG_HPA_1_10': '高价振幅_1_10',
#  'CJJG_LPA_1_10': '低价振幅_1_10',
#  'CJJG_HPTP_1_10': '高价成交占比_1_10',
#  'CJJG_LPTP_1_10': '低价成交占比_1_10',
#  'CJJG_VWR_1_10': '成交量加权反转_1_10',
#  'CJJG_HVTC_1_10': '高量交易成本_1_10',
#  'CJJG_HVPT_1_10': '高量每笔成交_1_10',
#  'CJJG_LVTC_1_10': '低量交易成本_1_10',
#  'CJJG_LVPT_1_10': '低量每笔成交_1_10',
#  'CJJG_HDTC_1_10': '高密度交易成本_1_10',
#  'CJJG_HDPT_1_10': '高密度每笔成交_1_10',
#  'CJJG_LDTC_1_10': '低密度交易成本_1_10',
#  'CJJG_LDPT_1_10': '低密度每笔成交_1_10',
#  'CJJG_MBP_1_10': '主买占比_1_10',
#  'CJJG_LSP_1_10': '量大单占比_1_10',
#  'CJJG_LSBP_1_10': '量大单买入占比_1_10',
#  'CJJG_STR_1_10': '短期反转_1_10',
#  'CJJG_STM_1_10': '短期动量_1_10',
#  'CJJG_STER_1_10': '短期加强反转_1_10',
#  'CJJG_ER_1_10': '极端收益_1_10',
#  'CJJG_PER_1_10': '极端前收益_1_10',
#  'CJJG_POER_1_10': '极端后收益_1_10',
#  'CJJG_LVR_1_10': '左端收益VaR_1_10',
#  'CJJG_RVR_1_10': '右端收益VaR_1_10',
#  'CJJG_LRPD_1_10': '左右概率差_1_10',
#  'CJJG_LVCVR_1_10': '左端收益CVaR_1_10',
#  'CJJG_UDVR_1_10': '右端收益CVaR_1_10',
#  'CJJG_UPDOWNVR_1_10': '上下行波动占比_1_10',
#  'CJJG_INFO_DISP_1_10': '信息离散度_1_10',
#  'CJJG_BETA_1_10': '每笔成交收益Beta_1_10',
#  'CJJG_BETA_1_20': '每笔成交收益Beta_1_20',
#  'CJJG_ILLQ_5_20': '非流动性_5_20',
#  'CJJG_TRAJILLQ_5_20': '轨迹非流动性_5_20',
#  'CJJG_UDILLQ_RATIO_5_20': '上下行非流动性比_5_20',
#  'CJJG_ILLQ_COEF_5_20': '非流动性变异系数_5_20',
#  'CJJG_PATHILLQ_5_20': '路径非流动性_5_20',
#  'CJJG_REGILLQ_5_20': '回归非流动性_5_20',
#  'CJJG_TURNOVER_COEF_5_20': '换手率变异系数_5_20',
#  'CJJG_BVOL_10_20': '基础波动率_10_20',
#  'CJJG_RSKEW_10_20': '收益偏度_10_20',
#  'CJJG_RKURT_10_20': '收益峰度_10_20',
#  'CJJG_COSKEW_10_20': '协偏度_10_20',
#  'CJJG_TVOL_10_20': '换手率波动率_10_20',
#  'CJJG_ENTROPY_10_20': '成交占比熵_10_20',
#  'CJJG_RVOL_10_20': '残差波动率_10_20',
#  'CJJG_RDSN_10_20': '残差偏度_10_20',
#  'CJJG_RDKT_10_20': '残差峰度_10_20',
#  'CJJG_SPEC_RATE_10_20': '特异率_10_20',
#  'CJJG_BVOL_10_10': '基础波动率_10_10',
#  'CJJG_RSKEW_10_10': '收益偏度_10_10',
#  'CJJG_RKURT_10_10': '收益峰度_10_10',
#  'CJJG_CS_10_10': '协偏度_10_10',
#  'CJJG_TV_10_10': '换手率波动率_10_10',
#  'CJJG_ENT_10_10': '成交占比熵_10_10',
#  'CJJG_RV_10_10': '残差波动率_10_10',
#  'CJJG_RDSN_10_10': '残差偏度_10_10',
#  'CJJG_RDKT_10_10': '残差峰度_10_10',
#  'CJJG_SR_10_10': '特异率_10_10',
#  'CJJG_TPR_60_20': '时量价比_60_20',
#  'CJJG_BV_60_20': '基础波动率_60_20',
#  'CJJG_RSKEW_60_20': '收益偏度_60_20',
#  'CJJG_RKURT_60_20': '收益峰度_60_20',
#  'CJJG_CS_60_20': '协偏度_60_20',
#  'CJJG_TV_60_20': '换手率波动率_60_20',
#  'CJJG_ENT_60_20': '成交占比熵_60_20',
#  'CJJG_RV_60_20': '残差波动率_60_20',
#  'CJJG_RDSN_60_20': '残差偏度_60_20',
#  'CJJG_RDKT_60_20': '残差峰度_60_20',
#  'CJJG_SR_60_20': '特异率_60_20',
#  'CJJG_ILLQ_60_20': '非流动性_60_20',
#  'CJJG_TRAJ_60_20': '轨迹非流动性_60_20',
#  'CJJG_UDIR_60_20': '上下行非流动性比_60_20',
#  'CJJG_ILLQ_COEF_60_20': '非流动性变异系数_60_20',
#  'CJJG_PATH_60_20': '路径非流动性_60_20',
#  'CJJG_REG_60_20': '回归非流动性_60_20',
#  'CJJG_TURNOVER_COEF_60_20': '换手率变异系数_60_20',
#  'CJJG_TPR_60_10': '时量价比_60_10',
#  'CJJG_BV_60_10': '基础波动率_60_10',
#  'CJJG_RSKEW_60_10': '收益偏度_60_10',
#  'CJJG_RKURT_60_10': '收益峰度_60_10',
#  'CJJG_CS_60_10': '协偏度_60_10',
#  'CJJG_TV_60_10': '换手率波动率_60_10',
#  'CJJG_ENT_60_10': '成交占比熵_60_10',
#  'CJJG_RV_60_10': '残差波动率_60_10',
#  'CJJG_RDSN_60_10': '残差偏度_60_10',
#  'CJJG_RDKT_60_10': '残差峰度_60_10',
#  'CJJG_SR_60_10': '特异率_60_10',
#  'CJJG_HCR_10': '半衰残差反转_10',
#  'CJJG_HCR_20': '半衰残差反转_20',
#  'CJJG_RHR_20': '相对最高回撤_20',
#  'CJJG_RHG_20': '相对最高涨幅_20',
#  'CJJG_NR_20': '普通反转_20',
#  'CJJG_PV_20': '每笔成交量_20',
#  'CJJG_PAV_20': '每笔成交额_20',
#  'CJJG_CA_20': '累计振幅_20',
#  'CJJG_CPTP_20': '集合成交占比_20',
#  'CJJG_LSP_20': '量大单强度_20',
#  'CJJG_LSBP_20': '量大单买入强度_20',
#  'CJJG_LSNBP_20': '量大单净买入强度_20',
#  'CJJG_LSPAVP_20': '量大每笔成交额占比_20',
#  'CJJG_LSPIP_20': '量大每笔流入额占比_20',
#  'CJJG_LSPOP_20': '量大每笔流出额占比_20',
#  'CJJG_LDC_20': '大单错位相关性_20',
#  'CJJG_DLCR_20': '驱动大单相关性_20',
#  'CJJG_SSDC_20': '小单错位相关性_20',
#  'CJJG_BP_20': '驱动小单相关性_20',
#  'CJJG_PLDPR_20': '笔大单占比_20',
#  'CJJG_BS_20': '笔大单买入占比_20',
#  'CJJG_BSN_20': '笔大单强度_20',
#  'CJJG_PIP_20': '笔大单净买入强度_20',
#  'CJJG_POP_20': '每笔流入额占比_20',
#  'CJJG_BPAVP_20': '每笔流出额占比_20',
#  'CJJG_PLPPBR_20': '笔大每笔成交额占比_20',
#  'CJJG_BOP_20': '笔大每笔流入额占比_20',
#  'CJJG_BDC_20': '笔大每笔流出额占比_20',
#  'CJJG_LPCS_20': '大笔错位相关性_20',
#  'CJJG_DLPC_20': '驱动大笔相关性_20',
#  'CJJG_PAQF_20': '小笔错位相关性_20',
#  'CJJG_RPQAF_20': '驱动小笔相关性_20',
#  'CJJG_CG_20': '每笔成交额分位数_20',
#  'CJJG_PK_20': '去异常每笔成交额分位数_20',
#  'CJJG_PPK_20': '重心_20',
#  'CJJG_BF_20': '波峰_20',
#  'CJJG_PPB_20': '每笔波峰_20',
#  'CJJG_NR_10': '普通反转_10',
#  'CJJG_PV_10': '每笔成交量_10',
#  'CJJG_PAV_10': '每笔成交额_10',
#  'CJJG_CA_10': '累计振幅_10',
#  'CJJG_CPTP_10': '集合成交占比_10',
#  'CJJG_LSP_10': '量大单强度_10',
#  'CJJG_LSBP_10': '量大单买入强度_10',
#  'CJJG_LSNBP_10': '量大单净买入强度_10',
#  'CJJG_LSPAVP_10': '量大每笔成交额占比_10',
#  'CJJG_LSPIP_10': '量大每笔流入额占比_10',
#  'CJJG_LSPOP_10': '量大每笔流出额占比_10',
#  'CJJG_LDC_10': '大单错位相关性_10',
#  'CJJG_DLCR_10': '驱动大单相关性_10',
#  'CJJG_SSDC_10': '小单错位相关性_10',
#  'CJJG_BP_10': '驱动小单相关性_10',
#  'CJJG_PLDPR_10': '笔大单占比_10',
#  'CJJG_BS_10': '笔大单买入占比_10',
#  'CJJG_BSN_10': '笔大单强度_10',
#  'CJJG_PIP_10': '笔大单净买入强度_10',
#  'CJJG_POP_10': '每笔流入额占比_10',
#  'CJJG_BPAVP_10': '每笔流出额占比_10',
#  'CJJG_PLPPBR_10': '笔大每笔成交额占比_10',
#  'CJJG_BOP_10': '笔大每笔流入额占比_10',
#  'CJJG_BDC_10': '笔大每笔流出额占比_10',
#  'CJJG_LPCS_10': '大笔错位相关性_10',
#  'CJJG_DLPC_10': '驱动大笔相关性_10',
#  'CJJG_PAQF_10': '小笔错位相关性_10',
#  'CJJG_RPQAF_10': '驱动小笔相关性_10',
#  'CJJG_CG_10': '每笔成交额分位数_10',
#  'CJJG_PK_10': '去异常每笔成交额分位数_10',
#  'CJJG_PPK_10': '重心_10',
#  'CJJG_BF_10': '波峰_10',
#  'CJJG_PPB_10': '每笔波峰_10',
#  'CJJG_APM_10': 'APM_10',
#  'CJJG_CFAPM_10': '集合替APM_10',
#  'CJJG_COAPM_10': '集合APM_10',
#  'CJJG_APM_20': 'APM_20',
#  'CJJG_CFAPM_20': '集合替APM_20',
#  'CJJG_COAPM_20': '集合APM_20',
#  'CJJG_TPR_20': '时量价比_20',
#  'CJJG_TPR_10': '时量价比_10',
#  'CJJG_PTL': '价格时滞'}

# %%
#训练集测试集划分，训练集放入全部正样本，负样本进行欠采样，预测时放入全部样本
#保留正样本，欠采样负样本
rus=RandomUnderSampler(sampling_strategy=0.1) #比例1：10
X_train_rus,y_train_rus=rus.fit_resample(X,y)
X_test,y_test=X,y

# %%
#统计当前类别占比情况
print("Before undersampling:",Counter(y))
# Out:
# Before undersampling: Counter({0: 36547, 1: 570})

# %%
#欠采样后类别占比情况
print("After undersampling:",Counter(y_train_rus))
# Out:
# After undersampling: Counter({0: 5700, 1: 570})

# %%
#训练多个模型并存储
#模型存储列表
models=[]

for i in range(30):
    rus=RandomUnderSampler(sampling_strategy=0.1) #比例1：10
    X_train_rus,y_train_rus=rus.fit_resample(X,y)
    xgb_model=XGBClassifier()
    xgb_model.fit(X_train_rus,y_train_rus)
    
    #特征重要性（SHAP值）
    explainer=shap.Explainer(xgb_model)
    shape_value=explainer.shap_values(X)
    shap_df=pd.DataFrame(shape_value,columns=X_train_rus.columns)
    #输出每个特征的SHAP值（绝对值）
    features=[]
    shap_values_means=[]
    for index,feature in enumerate(X_train_rus.columns):
        shap_values_mean=np.abs(shap_df.values[:,index]).mean()
        features.append(feature)
        shap_values_means.append(shap_values_mean)
    tt=pd.DataFrame(features,columns=['features'])
    tt['shap_values']=shap_values_means
    tt_sort=tt.sort_values(by='shap_values',ascending=False)
    tt_sort.to_csv(f'data/fund/xgb_{fund_name}_feature_importance{i}.csv',index=False)
    
    #保存模型
    model_filename=f'data/fund/xgb_{fund_name}_model_{i}.pkl'
    joblib.dump(xgb_model,model_filename)
    models.append(xgb_model)
X_train_rus,y_train_rus=rus.fit_resample(X,y)

# %%
#加载所有保存的模型
models=[joblib.load(f'data/fund/xgb_{fund_name}_model_{i}.pkl') for i in range(30)]

#对所有模型进行投票集成,选择硬投票或软投票(基于概率）
voting_clf=VotingClassifier(estimators=[(f'xgb_{fund_name}_model_{i}',model) for i,model in enumerate(models)],
                            voting='soft')
voting_clf.fit(X_train_rus,y_train_rus)
#保存模型
model_filename=f'data/fund/voting_{fund_name}_model.pkl'
joblib.dump(voting_clf,model_filename)
y_pred=voting_clf.predict(X_test)
metric_score(test_y=y_test,pre_y=y_pred)
# Out:
# Recall:1.000
# Precision:0.589
# F1:0.742

# %%
#查看模型预测为1，实际为0的股票
#原始数据处理
result_df1=y_code.reset_index()
result_copy=result_df1.copy()
result_copy['y_true']=y_test
result_copy['y_pred']=y_pred

false_pos=result_copy[(result_copy['y_pred']==1) & (result_copy['y_true']==0)]
#合并股票名称
false_pos_df1=pd.merge(false_pos['CJJG_CODE'],stockcode_name,left_on='CJJG_CODE',right_on='STOCKCODE',how='inner')
#添加重复次数列
false_pos_df1['count']=false_pos_df1.groupby('STOCKCODE')['STOCKCODE'].transform('count')
false_pos_df1=false_pos_df1[['STOCKCODE','SESNAME','count']].drop_duplicates().reset_index(drop=True)
false_pos_df1.to_csv(f'data/fund/voting_{fund_name}_model_predict.csv',index=False)

# %%
#默认阈值一般为0.5
y_pred_recall=y_pred[0:]>0.5
cnf_matrix=confusion_matrix(y_test,y_pred_recall)
class_names=[0,1]
plot_confusion_matrix(cnf_matrix,classes=class_names,fund_name=fund_name)

# %%
#读取股票名文件
voting_result=pd.read_csv(f'data/fund/voting_{fund_name}_model_predict.csv')
voting_result
# Out:
#      STOCKCODE SESNAME  count
# 0    601009.SH    南京银行      4
# 1    600104.SH    上汽集团      1
# 2    601088.SH    中国神华      5
# 3    601966.SH    玲珑轮胎      2
# 4    601985.SH    中国核电      2
# ..         ...     ...    ...
# 216  002415.SZ    海康威视      1
# 217  000895.SZ    双汇发展      1
# 218  002128.SZ    电投能源      1
# 219  000900.SZ    现代投资      1
# 220  603568.SH    伟明环保      1
#
# [221 rows x 3 columns]

# %%
#特征重要性读取
feature_file_names=[f'data/fund/xgb_{fund_name}_feature_importance{i}.csv' for i in range(30)]

importance_features = []     
for file in feature_file_names:
    df=pd.read_csv(file)
    importance_features.append(df)
    
#横向拼接所有数据
importance_all=pd.concat(importance_features)

#按特征分组，计算特征重要性平均值，并排序
importance_summary=(importance_all.groupby('features')['shap_values'].agg(['mean','std']).reset_index().sort_values(by='mean',ascending=False))

# %%
importance_summary
# Out:
#                   features      mean       std
# 72             CJJG_ILQ_60  0.574662  0.083404
# 60         CJJG_ENIROE_TTM  0.563884  0.093437
# 69                CJJG_ILQ  0.519864  0.052756
# 34                 CJJG_DP  0.352483  0.079432
# 76              CJJG_KU_60  0.307300  0.041660
# ..                     ...       ...       ...
# 101  CJJG_NOPLAT2EV_12_TTM  0.000000  0.000000
# 99          CJJG_NOPLAT2EV  0.000000  0.000000
# 104    CJJG_NOPLAT_TTM_YOY  0.000000  0.000000
# 105        CJJG_NOPLAT_YOY  0.000000  0.000000
# 100      CJJG_NOPLAT2EV_12  0.000000  0.000000
#
# [165 rows x 3 columns]

# %%
#替换特征名字，如果找不到映射，使用原名字
mapping_features=[mapping_dict.get(feature) for feature in importance_summary['features'][:15]]
mapping_features
# Out:
# ['非流动性_60',
#  '扣非ROE_TTM',
#  '非流动性',
#  'DP',
#  '峰度_60',
#  'ROE_TTM',
#  '研发费用比例_TTM',
#  '非流动性_20',
#  '换手率_60',
#  '空头意愿',
#  '非流动性_10',
#  '波动率_240',
#  '峰度_10',
#  '动量_240',
#  'DP_TTM']

# %%
plt.barh(mapping_features,importance_summary['mean'][:15],xerr=importance_summary['std'][:15],capsize=5)
plt.xlabel(f'{fund_name}_Importance(Mean)',fontsize=14)
plt.ylabel('Feature',fontsize=14)
plt.gca().invert_yaxis()
plt.tight_layout()
plt.savefig(f'data/fund/fig/{fund_name}_Importance(Mean).svg')

# %%
#相关股票数据信息读取与处理
fund_names_path='data/fund/eda/months_df.csv'
months_path='data/fund/eda/fund_names_df.csv'
fund_names,months_list=clean_and_split_months(fund_names_path,months_path)

# %%
len(fund_names)
# Out:
# 28

# %%
#DP的SHAP值小于0.1且正样本过少：004098.OF({0: 8701, 1: 3}),563180.OF({0: 4362, 1: 10}),007178.OF({0: 2974, 1: 2}),007216.OF({0: 2974, 1: 2})，015290.OF({0: 12878, 1: 19})，015289.OF({0: 12878, 1: 19})
remove_list=['004098.OF','563180.OF','007178.OF','007216.OF','015290.OF','015289.OF']
fund_names=[item for item in fund_names if item not in remove_list]

# %%
len(fund_names)
# Out:
# 22

# %%
fund_name=fund_names[0]

# %%
for i,fund_name in enumerate(fund_names):
    print(fund_name)
# Out:
# 005770.OF
# 004404.OF
# 006124.OF
# 004403.OF
# 008705.OF
# 008737.OF
# 501308.OF
# 512590.OF
# 009501.OF
# 515690.OF
# 008480.OF
# 008481.OF
# 004868.OF
# 501307.OF
# 006123.OF
# 009500.OF
# 003702.OF
# 000916.OF
# 008736.OF
# 008177.OF
# 008704.OF
# 009188.OF

# %%
fund_name=fund_names[7]

# %%
#特征重要性读取
for fund_name in fund_names:
    base_dir=f'data/fund/model/{fund_name}'
    feature_file_names=[f'{base_dir}/xgb_{fund_name}_feature_importance{i}.csv' for i in range(30)]
    
    importance_features = []     
    for file in feature_file_names:
        df=pd.read_csv(file)
        importance_features.append(df)
        
    #横向拼接所有数据
    importance_all=pd.concat(importance_features)
    
    #按特征分组，计算特征重要性平均值，并排序
    importance_summary=(importance_all.groupby('features')['shap_values'].agg(['mean','std']).reset_index().sort_values(by='mean',ascending=False))
    
    #替换特征名字，如果找不到映射，使用原名字
    mapping_features=[mapping_dict.get(feature) for feature in importance_summary['features'][:15]]
    
    plt.barh(mapping_features,importance_summary['mean'][:15],xerr=importance_summary['std'][:15],capsize=5)
    plt.xlabel(f'{fund_name}_Importance(Mean)',fontsize=14)
    plt.ylabel('Feature',fontsize=14)
    plt.gca().invert_yaxis()
    plt.tight_layout()
    plt.savefig(f'data/fund/fig/{fund_name}_Importance(Mean).svg')

# %% [markdown]
# ### top5feature筛选方案

# %%
#所有基金的top5特征列表
top5_features_list=[]
for fund_name in fund_names:
    base_dir=f'data/fund/model/{fund_name}'
    feature_file_names=[f'{base_dir}/xgb_{fund_name}_feature_importance{i}.csv' for i in range(30)]
    
    importance_features = []     
    for file in feature_file_names:
        df=pd.read_csv(file)
        importance_features.append(df)
        
    #横向拼接所有数据
    importance_all=pd.concat(importance_features)
    
    #按特征分组，计算特征重要性平均值，并排序
    importance_summary=(importance_all.groupby('features')['shap_values'].agg(['mean','std']).reset_index().sort_values(by='mean',ascending=False))
    
    #基于SHAP平均值选择top5的特征
    top5_features=importance_summary.head(5)

    
    top5_features_list.append(top5_features)
    
    # #替换特征名字，如果找不到映射，使用原名字
    # mapping_features=[mapping_dict.get(feature) for feature in top15_features['features']]

# %%
len(top5_features_list)
# Out:
# 22

# %%
feature_counter=Counter()   #特征出现次数
all_feature_sets=[]     #特征名字
for top5_features in top5_features_list:
    feature_names=set(top5_features['features'])
    feature_counter.update(top5_features['features']) #计数
    all_feature_sets.append(feature_names)

# %%
#字典转换为Dataframe
stock_frequency_df=pd.DataFrame(feature_counter.items(),columns=['name','frequency'])

#按出现次数降序
stock_frequency_df=stock_frequency_df.sort_values(by='frequency',ascending=False)
stock_frequency_df
# Out:
#                   name  frequency
# 5             CJJG_ILQ         15
# 1              CJJG_DP         13
# 6          CJJG_ILQ_60         12
# 8          CJJG_DP_TTM         12
# 9         CJJG_MOM_240          7
# 7         CJJG_VOL_240          5
# 18         CJJG_KU_240          5
# 13            CJJG_PFT          5
# 10     CJJG_ENIROE_TTM          4
# 2   CJJG_NCFOA_TTM_YOY          3
# 3      CJJG_ENIROA_TTM          3
# 19          CJJG_TR_60          3
# 14  CJJG_EBITDA2EV_TTM          2
# 17        CJJG_ROA_TTM          2
# 21            CJJG_DSO          2
# 11          CJJG_KU_60          2
# 15         CJJG_ILQ_10          2
# 12         CJJG_MDR_60          2
# 26           CJJG_RNPG          1
# 23            CJJG_RRG          1
# 25         CJJG_ILQ_20          1
# 27           CJJG_ANPG          1
# 24            CJJG_POG          1
# 0         CJJG_ARR_TTM          1
# 22       CJJG_PORE_TTM          1
# 20         CJJG_MIR_60          1
# 16             CJJG_LR          1
# 4             CJJG_ARG          1
# 28       CJJG_NPAT_YOY          1

# %%
#替换特征名字，如果找不到映射，使用原名字
mapping_features=[mapping_dict.get(feature) for feature in stock_frequency_df['name'][:15]]

# %%
plt.barh(mapping_features,stock_frequency_df['frequency'][:15])
plt.xlabel('Frequency',fontsize=14)
plt.ylabel('Features',fontsize=14)
plt.gca().set_xticks(range(0,20,2))
plt.gca().invert_yaxis()
plt.tight_layout()
# plt.savefig(f'data/fund/fig/TOP5_feature.svg')
# plt.close()

# %%
#共同的特征名字（并集）
# common_features=reduce(lambda x,y: x|y,all_feature_sets)
common_features=stock_frequency_df.reset_index(drop=True)
common_features
# Out:
#                   name  frequency
# 0             CJJG_ILQ         15
# 1              CJJG_DP         13
# 2          CJJG_ILQ_60         12
# 3          CJJG_DP_TTM         12
# 4         CJJG_MOM_240          7
# 5         CJJG_VOL_240          5
# 6          CJJG_KU_240          5
# 7             CJJG_PFT          5
# 8      CJJG_ENIROE_TTM          4
# 9   CJJG_NCFOA_TTM_YOY          3
# 10     CJJG_ENIROA_TTM          3
# 11          CJJG_TR_60          3
# 12  CJJG_EBITDA2EV_TTM          2
# 13        CJJG_ROA_TTM          2
# 14            CJJG_DSO          2
# 15          CJJG_KU_60          2
# 16         CJJG_ILQ_10          2
# 17         CJJG_MDR_60          2
# 18           CJJG_RNPG          1
# 19            CJJG_RRG          1
# 20         CJJG_ILQ_20          1
# 21           CJJG_ANPG          1
# 22            CJJG_POG          1
# 23        CJJG_ARR_TTM          1
# 24       CJJG_PORE_TTM          1
# 25         CJJG_MIR_60          1
# 26             CJJG_LR          1
# 27            CJJG_ARG          1
# 28       CJJG_NPAT_YOY          1

# %%
#替换特征名字，如果找不到映射，使用原名字
common_mapping_features=[mapping_dict.get(feature) for feature in common_features['name']]

# %%
common_mapping_features
# Out:
# ['非流动性',
#  'DP',
#  '非流动性_60',
#  'DP_TTM',
#  '动量_240',
#  '波动率_240',
#  '峰度_240',
#  '盈利',
#  '扣非ROE_TTM',
#  '经营活动现金流净额_TTM_同比',
#  '扣非ROA_TTM',
#  '换手率_60',
#  'EBITDA2EV_TTM',
#  'ROA_TTM',
#  '应收账款周转天数',
#  '峰度_60',
#  '非流动性_10',
#  '最大跌幅_60',
#  '相对净利润增长',
#  '相对营收增长',
#  '非流动性_20',
#  '绝对净利润增长',
#  '商誉占比',
#  '资产报酬率_TTM',
#  '研发费用比例_TTM',
#  '最大涨幅_60',
#  '杠杆率',
#  '绝对营收增长',
#  '归母净利润_同比']

# %%
common_features['name']=common_mapping_features
common_features
# Out:
#                 name  frequency
# 0               非流动性         15
# 1                 DP         13
# 2            非流动性_60         12
# 3             DP_TTM         12
# 4             动量_240          7
# 5            波动率_240          5
# 6             峰度_240          5
# 7                 盈利          5
# 8          扣非ROE_TTM          4
# 9   经营活动现金流净额_TTM_同比          3
# 10         扣非ROA_TTM          3
# 11            换手率_60          3
# 12     EBITDA2EV_TTM          2
# 13           ROA_TTM          2
# 14          应收账款周转天数          2
# 15             峰度_60          2
# 16           非流动性_10          2
# 17           最大跌幅_60          2
# 18           相对净利润增长          1
# 19            相对营收增长          1
# 20           非流动性_20          1
# 21           绝对净利润增长          1
# 22              商誉占比          1
# 23         资产报酬率_TTM          1
# 24        研发费用比例_TTM          1
# 25           最大涨幅_60          1
# 26               杠杆率          1
# 27            绝对营收增长          1
# 28          归母净利润_同比          1

# %%
common_features.columns=['feature','frequency']

# %%
common_features
# Out:
#              feature  frequency
# 0               非流动性         15
# 1                 DP         13
# 2            非流动性_60         12
# 3             DP_TTM         12
# 4             动量_240          7
# 5            波动率_240          5
# 6             峰度_240          5
# 7                 盈利          5
# 8          扣非ROE_TTM          4
# 9   经营活动现金流净额_TTM_同比          3
# 10         扣非ROA_TTM          3
# 11            换手率_60          3
# 12     EBITDA2EV_TTM          2
# 13           ROA_TTM          2
# 14          应收账款周转天数          2
# 15             峰度_60          2
# 16           非流动性_10          2
# 17           最大跌幅_60          2
# 18           相对净利润增长          1
# 19            相对营收增长          1
# 20           非流动性_20          1
# 21           绝对净利润增长          1
# 22              商誉占比          1
# 23         资产报酬率_TTM          1
# 24        研发费用比例_TTM          1
# 25           最大涨幅_60          1
# 26               杠杆率          1
# 27            绝对营收增长          1
# 28          归母净利润_同比          1

# %%
common_features.to_csv(f'data/fund/analyze/top5feature_union.csv', encoding='utf-8',index=False)

# %%
range(0,20,2)
# Out:
# range(0, 20, 2)

# %% [markdown]
# ### 覆盖率80%重要性的feature筛选方案

# %%
#覆盖率80%重要性的特征列表
tmp1=[]
coverage80_features_list=[]
for fund_name in fund_names:
    base_dir=f'data/fund/model/{fund_name}'
    feature_file_names=[f'{base_dir}/xgb_{fund_name}_feature_importance{i}.csv' for i in range(30)]
    
    importance_features = []     
    for file in feature_file_names:
        df=pd.read_csv(file)
        importance_features.append(df)
        
    #横向拼接所有数据
    importance_all=pd.concat(importance_features)
    
    #按特征分组，计算特征重要性平均值，并排序
    importance_summary=(importance_all.groupby('features')['shap_values'].agg(['mean','std']).reset_index().sort_values(by='mean',ascending=False))
    
    #选择SHAP值覆盖总重要性的80%的特征
    total_shap=importance_summary['mean'].sum()
    importance_summary['shap_cumsum']=importance_summary['mean'].cumsum()
    shap_80_percent_coverage=importance_summary[importance_summary['shap_cumsum']<=0.8*total_shap]
    tmp1.append(fund_name)
    tmp1.append(total_shap)
    print(total_shap)
    
    coverage80_features_list.append(shap_80_percent_coverage)
# Out:
# 14.400184490426666
# 13.525080895426
# 13.129840538116667
# 13.420938236954
# 10.752992444183333
# 13.096832854350001
# 13.277992899533334
# 12.931868689529999
# 11.683672559720002
# 11.201294787998332
# 12.339127238130999
# 12.34370879002
# 12.723367313446666
# 13.314746109152333
# 13.117619578628666
# 11.620951742239999
# 13.875141920473332
# 12.047656694599999
# 13.099849039418332
# 11.666758678303331
# 10.730818430189998
# 11.882112731545668

# %%
importance_summary
# Out:
#                   features      mean       std  shap_cumsum
# 118               CJJG_PFT  0.399412  0.056909     0.399412
# 69                CJJG_ILQ  0.354441  0.047739     0.753853
# 2                CJJG_ANPG  0.322223  0.043138     1.076076
# 107          CJJG_NPAT_YOY  0.309728  0.088188     1.385804
# 158             CJJG_TR_60  0.201425  0.036921     1.587229
# ..                     ...       ...       ...          ...
# 104    CJJG_NOPLAT_TTM_YOY  0.000000  0.000000    11.882113
# 100      CJJG_NOPLAT2EV_12  0.000000  0.000000    11.882113
# 105        CJJG_NOPLAT_YOY  0.000000  0.000000    11.882113
# 101  CJJG_NOPLAT2EV_12_TTM  0.000000  0.000000    11.882113
# 102     CJJG_NOPLAT2EV_TTM  0.000000  0.000000    11.882113
#
# [165 rows x 4 columns]

# %%
feature_counter=Counter()   #特征出现次数
for coverage80_features in coverage80_features_list:
    stock_names=set(coverage80_features['features'])
    feature_counter.update(coverage80_features['features']) #计数
    
#字典转换为Dataframe
stock_frequency_df=pd.DataFrame(feature_counter.items(),columns=['name','frequency'])

#按出现次数降序
stock_frequency_df=stock_frequency_df.sort_values(by=['frequency','name'],ascending=[False,True])
stock_frequency_df
# Out:
#                 name  frequency
# 81      CJJG_BETA_60         22
# 1            CJJG_DP         22
# 30          CJJG_ILQ         22
# 19       CJJG_ILQ_10         22
# 7        CJJG_ILQ_60         22
# ..               ...        ...
# 149         CJJG_GPM          1
# 150         CJJG_NPM          1
# 151      CJJG_NP_YOY          1
# 146  CJJG_RES_VOL_20          1
# 148         CJJG_ROE          1
#
# [153 rows x 2 columns]

# %%
#替换特征名字，如果找不到映射，使用原名字
mapping_features=[mapping_dict.get(feature) for feature in stock_frequency_df['name'][:15]]

# %%
mapping_features
# Out:
# ['Beta_60',
#  'DP',
#  '非流动性',
#  '非流动性_10',
#  '非流动性_60',
#  '应收账款占比',
#  '流动资产比例',
#  '三项费用比例_TTM',
#  '商誉占比',
#  '换手率_60',
#  '空头意愿',
#  'DP_TTM',
#  '非流动性_20',
#  '动量_240',
#  '反转_60']

# %%
plt.barh(mapping_features,stock_frequency_df['frequency'][:15])
plt.xlabel('Frequency',fontsize=14)
plt.ylabel('Features',fontsize=14)
# plt.gca().set_xticks(range(0,20,2))
plt.gca().invert_yaxis()
plt.tight_layout()
# plt.savefig(f'data/fund/fig/Coverage80_feature.svg')
# plt.close()

# %% [markdown]
# ### DP特征指标80%以上卡阈值的feature筛选方案

# %%
#DP特征指标80%以上卡阈值的特征列表
#DP的SHAP值为0：004098.OF({0: 8701, 1: 3}),563180.OF({0: 4362, 1: 10}),007178.OF({0: 2974, 1: 2}),007216.OF({0: 2974, 1: 2})
#DP的SHAP值小于0.1：015290.OF({0: 12878, 1: 19})，015289.OF({0: 12878, 1: 19})，009188.OF({0.0: 30744, 1.0: 516})
tmp=[]
DP80_features_list=[]
for fund_name in fund_names:
    base_dir=f'data/fund/model/{fund_name}'
    feature_file_names=[f'{base_dir}/xgb_{fund_name}_feature_importance{i}.csv' for i in range(30)]
    
    importance_features = []     
    for file in feature_file_names:
        df=pd.read_csv(file)
        importance_features.append(df)
        
    #横向拼接所有数据
    importance_all=pd.concat(importance_features)
    
    #按特征分组，计算特征重要性平均值，并排序
    importance_summary=(importance_all.groupby('features')['shap_values'].agg(['mean','std']).reset_index().sort_values(by='mean',ascending=False))
    
    #选择DP特征重要性大于80%的特征
    dp_threshold=importance_summary[importance_summary['features']=='CJJG_DP']['mean']*0.8
    DP80_features=importance_summary[importance_summary['mean'].values>=dp_threshold.values]
    
    print(fund_name)
    print(importance_summary[importance_summary['features']=='CJJG_DP']['mean'])
    tmp.append(fund_name)
    tmp.append(importance_summary[importance_summary['features']=='CJJG_DP']['mean'])
    
    DP80_features_list.append(DP80_features)
# Out:
# 005770.OF
# 34    0.633994
# Name: mean, dtype: float64
# 004404.OF
# 34    0.257306
# Name: mean, dtype: float64
# 006124.OF
# 34    0.360071
# Name: mean, dtype: float64
# 004403.OF
# 34    0.281798
# Name: mean, dtype: float64
# 008705.OF
# 34    0.196134
# Name: mean, dtype: float64
# 008737.OF
# 34    0.502796
# Name: mean, dtype: float64
# 501308.OF
# 34    1.010561
# Name: mean, dtype: float64
# 512590.OF
# 34    0.47391
# Name: mean, dtype: float64
# 009501.OF
# 34    0.449918
# Name: mean, dtype: float64
# 515690.OF
# 34    0.248942
# Name: mean, dtype: float64
# 008480.OF
# 34    0.139924
# Name: mean, dtype: float64
# 008481.OF
# 34    0.13673
# Name: mean, dtype: float64
# 004868.OF
# 34    0.1358
# Name: mean, dtype: float64
# 501307.OF
# 34    0.983813
# Name: mean, dtype: float64
# 006123.OF
# 34    0.341719
# Name: mean, dtype: float64
# 009500.OF
# 34    0.462031
# Name: mean, dtype: float64
# 003702.OF
# 34    0.151402
# Name: mean, dtype: float64
# 000916.OF
# 34    0.784395
# Name: mean, dtype: float64
# 008736.OF
# 34    0.536493
# Name: mean, dtype: float64
# 008177.OF
# 34    0.106067
# Name: mean, dtype: float64
# 008704.OF
# 34    0.203691
# Name: mean, dtype: float64
# 009188.OF
# 34    0.066831
# Name: mean, dtype: float64

# %%
DP80_features_list
# Out:
# [              features      mean       std
#  5         CJJG_ARR_TTM  0.758694  0.114296
#  34             CJJG_DP  0.625474  0.119815
#  97  CJJG_NCFOA_TTM_YOY  0.542707  0.045696,
#              features      mean       std
#  69          CJJG_ILQ  1.173234  0.101370
#  72       CJJG_ILQ_60  0.771472  0.076374
#  161     CJJG_VOL_240  0.642211  0.067780
#  35       CJJG_DP_TTM  0.545213  0.081319
#  96      CJJG_MOM_240  0.346626  0.058052
#  34           CJJG_DP  0.275778  0.077368
#  60   CJJG_ENIROE_TTM  0.263108  0.077503,
#             features      mean       std
#  36         CJJG_DSO  0.216003  0.241097
#  110        CJJG_PAR  0.164139  0.199449
#  37     CJJG_DSO_TTM  0.148702  0.243351
#  116       CJJG_PORE  0.132141  0.188676
#  5      CJJG_ARR_TTM  0.114071  0.163829
#  ..              ...       ...       ...
#  93   CJJG_NOPLAT2EV  0.000000  0.000000
#  29         CJJG_CVP  0.000000  0.000000
#  31     CJJG_DIO_TTM  0.000000  0.000000
#  33     CJJG_DNP_YOY  0.000000  0.000000
#  0          CJJG_ALR  0.000000  0.000000
#
#  [159 rows x 3 columns],
#               features      mean       std
#  130       CJJG_REV_20  0.493808  0.116901
#  89        CJJG_MDD_60  0.338808  0.150578
#  139          CJJG_RRG  0.328465  0.161189
#  98     CJJG_NCFOA_YOY  0.298738  0.145813
#  26      CJJG_CTAR_TTM  0.283552  0.193601
#  ..                ...       ...       ...
#  39      CJJG_DTAT_TTM  0.005939  0.013048
#  122         CJJG_PORE  0.005780  0.012794
#  159       CJJG_VOL_10  0.005667  0.018083
#  41   CJJG_EBIT2BI_TTM  0.005361  0.011226
#  55      CJJG_EBIT_YOY  0.004889  0.011793
#
#  [138 rows x 3 columns],
#              features      mean       std
#  72       CJJG_ILQ_60  0.583585  0.074662
#  60   CJJG_ENIROE_TTM  0.558573  0.078414
#  69          CJJG_ILQ  0.534334  0.047554
#  34           CJJG_DP  0.340362  0.078429
#  138     CJJG_ROE_TTM  0.317622  0.069908
#  76        CJJG_KU_60  0.310128  0.035045
#  123    CJJG_PORE_TTM  0.279480  0.054895,
#              features      mean       std
#  69          CJJG_ILQ  1.194482  0.058481
#  72       CJJG_ILQ_60  0.779661  0.081858
#  161     CJJG_VOL_240  0.646716  0.071237
#  35       CJJG_DP_TTM  0.509047  0.086200
#  96      CJJG_MOM_240  0.350143  0.053982
#  34           CJJG_DP  0.297095  0.068553
#  60   CJJG_ENIROE_TTM  0.266493  0.082092,
#           features      mean       std
#  92    CJJG_MDR_60  0.989415  0.039004
#  69       CJJG_ILQ  0.418462  0.034269
#  161  CJJG_VOL_240  0.282631  0.031355
#  35    CJJG_DP_TTM  0.240560  0.041519
#  34        CJJG_DP  0.183963  0.049853
#  72    CJJG_ILQ_60  0.179422  0.020368
#  91    CJJG_MDR_20  0.150345  0.028167,
#             features      mean       std
#  69         CJJG_ILQ  1.089741  0.090987
#  34          CJJG_DP  0.516697  0.094123
#  60  CJJG_ENIROE_TTM  0.417630  0.097829,
#         features      mean       std
#  35  CJJG_DP_TTM  1.240068  0.220348
#  34      CJJG_DP  0.981867  0.214616,
#                 features      mean       std
#  58      CJJG_ENIROA_TTM  0.567270  0.073211
#  34              CJJG_DP  0.449936  0.063411
#  97   CJJG_NCFOA_TTM_YOY  0.377310  0.028815
#  77              CJJG_LR  0.374665  0.053383
#  134        CJJG_ROA_TTM  0.370346  0.082710,
#                  features      mean       std
#  69              CJJG_ILQ  0.745025  0.593359
#  10          CJJG_BETA_60  0.567001  0.446686
#  44   CJJG_EBIT2EV_12_TTM  0.242596  0.273890
#  70           CJJG_ILQ_10  0.096987  0.222951
#  152           CJJG_TR_60  0.096447  0.163686
#  ..                   ...       ...       ...
#  51    CJJG_EBITDA2EV_TTM  0.000000  0.000000
#  49     CJJG_EBITDA2EV_12  0.000000  0.000000
#  48        CJJG_EBITDA2EV  0.000000  0.000000
#  47    CJJG_EBITDA2BI_TTM  0.000000  0.000000
#  158              CJJG_WS  0.000000  0.000000
#
#  [159 rows x 3 columns],
#         features      mean       std
#  69     CJJG_ILQ  0.679009  0.084571
#  34      CJJG_DP  0.443973  0.155513
#  72  CJJG_ILQ_60  0.421680  0.100621
#  75  CJJG_KU_240  0.379710  0.086502,
#           features      mean       std
#  69       CJJG_ILQ  1.694249  0.146473
#  72    CJJG_ILQ_60  1.089074  0.085442
#  161  CJJG_VOL_240  0.437963  0.107538
#  95    CJJG_MIR_60  0.325404  0.088557
#  158    CJJG_TR_60  0.271461  0.072035
#  35    CJJG_DP_TTM  0.248638  0.076750
#  34        CJJG_DP  0.244492  0.093216
#  120  CJJG_POE_TTM  0.217887  0.083945,
#                 features      mean       std
#  69             CJJG_ILQ  0.988266  0.098700
#  72          CJJG_ILQ_60  0.659408  0.065138
#  36             CJJG_DSO  0.316980  0.055251
#  96         CJJG_MOM_240  0.316247  0.078324
#  75          CJJG_KU_240  0.303443  0.062358
#  158          CJJG_TR_60  0.292181  0.054305
#  29             CJJG_CVP  0.221666  0.053210
#  76           CJJG_KU_60  0.211947  0.050319
#  18            CJJG_CNPR  0.202708  0.036782
#  35          CJJG_DP_TTM  0.188308  0.052161
#  60      CJJG_ENIROE_TTM  0.177357  0.063920
#  123       CJJG_PORE_TTM  0.166728  0.058825
#  11              CJJG_BI  0.164060  0.043433
#  131         CJJG_REV_60  0.163575  0.035636
#  150             CJJG_SR  0.160823  0.056162
#  97   CJJG_NCFOA_TTM_YOY  0.154903  0.036616
#  34              CJJG_DP  0.144996  0.048352
#  121            CJJG_POG  0.138620  0.050344
#  132           CJJG_RNPG  0.132091  0.036962
#  79           CJJG_MA_10  0.130232  0.041739
#  94          CJJG_MIR_20  0.129760  0.047873
#  153          CJJG_SR_60  0.120696  0.032907,
#                 features      mean       std
#  69             CJJG_ILQ  0.991034  0.091574
#  72          CJJG_ILQ_60  0.652884  0.065880
#  96         CJJG_MOM_240  0.306477  0.098161
#  75          CJJG_KU_240  0.290794  0.075458
#  36             CJJG_DSO  0.289261  0.056525
#  158          CJJG_TR_60  0.262895  0.051531
#  76           CJJG_KU_60  0.235147  0.050725
#  29             CJJG_CVP  0.213273  0.050707
#  35          CJJG_DP_TTM  0.199674  0.041736
#  18            CJJG_CNPR  0.194750  0.042168
#  150             CJJG_SR  0.192111  0.046556
#  123       CJJG_PORE_TTM  0.185148  0.064124
#  97   CJJG_NCFOA_TTM_YOY  0.168649  0.047791
#  60      CJJG_ENIROE_TTM  0.166545  0.074648
#  131         CJJG_REV_60  0.157645  0.034506
#  79           CJJG_MA_10  0.151039  0.057291
#  11              CJJG_BI  0.150618  0.040697
#  34              CJJG_DP  0.146987  0.043762
#  85          CJJG_MCI_20  0.128538  0.043679
#  8          CJJG_BETA_10  0.123336  0.033271,
#                 features      mean       std
#  118            CJJG_PFT  0.735343  0.066828
#  72          CJJG_ILQ_60  0.457704  0.041846
#  75          CJJG_KU_240  0.451550  0.058490
#  123       CJJG_PORE_TTM  0.364536  0.039791
#  139            CJJG_RRG  0.310054  0.055472
#  36             CJJG_DSO  0.252461  0.046215
#  68        CJJG_IC2EV_12  0.249240  0.069845
#  37         CJJG_DSO_TTM  0.209735  0.046040
#  161        CJJG_VOL_240  0.205887  0.028954
#  150             CJJG_SR  0.195069  0.042695
#  158          CJJG_TR_60  0.189052  0.034806
#  120        CJJG_POE_TTM  0.165195  0.042700
#  60      CJJG_ENIROE_TTM  0.153641  0.060690
#  119            CJJG_POE  0.152880  0.035852
#  34              CJJG_DP  0.147013  0.040612
#  97   CJJG_NCFOA_TTM_YOY  0.145903  0.036331
#  154            CJJG_STM  0.144672  0.040157
#  88          CJJG_MDD_20  0.143367  0.047458
#  71          CJJG_ILQ_20  0.141147  0.027669
#  76           CJJG_KU_60  0.130197  0.039024
#  11              CJJG_BI  0.128378  0.026115
#  95          CJJG_MIR_60  0.126485  0.024526
#  117            CJJG_PCA  0.124706  0.028063
#  151          CJJG_SR_10  0.120873  0.029443
#  58      CJJG_ENIROA_TTM  0.119861  0.049359,
#         features      mean       std
#  35  CJJG_DP_TTM  1.225787  0.234733
#  34      CJJG_DP  0.973809  0.217487,
#                  features      mean       std
#  98        CJJG_NCFOA_YOY  0.140238  0.074348
#  138         CJJG_ROE_TTM  0.066277  0.095137
#  69              CJJG_ILQ  0.062906  0.096470
#  163              CJJG_WC  0.048689  0.088503
#  0               CJJG_ALR  0.045549  0.081428
#  ..                   ...       ...       ...
#  43       CJJG_EBIT2EV_12  0.000000  0.000000
#  92           CJJG_MDR_60  0.000000  0.000000
#  91           CJJG_MDR_20  0.000000  0.000000
#  44   CJJG_EBIT2EV_12_TTM  0.000000  0.000000
#  82             CJJG_MBPM  0.000000  0.000000
#
#  [165 rows x 3 columns],
#                    features      mean       std
#  130            CJJG_REV_20  0.432859  0.204810
#  139               CJJG_RRG  0.359923  0.162133
#  89             CJJG_MDD_60  0.342910  0.163354
#  26           CJJG_CTAR_TTM  0.319138  0.199748
#  136           CJJG_ROC_TTM  0.281831  0.211753
#  ..                     ...       ...       ...
#  85             CJJG_MCI_20  0.002071  0.011345
#  92             CJJG_MDR_60  0.002060  0.008023
#  50   CJJG_EBITDA2EV_12_TTM  0.001968  0.010778
#  34                 CJJG_DP  0.001957  0.010719
#  12                 CJJG_BP  0.001664  0.005498
#
#  [152 rows x 3 columns],
#              features      mean       std
#  60   CJJG_ENIROE_TTM  0.599850  0.093410
#  72       CJJG_ILQ_60  0.593330  0.073301
#  69          CJJG_ILQ  0.534839  0.059921
#  34           CJJG_DP  0.331827  0.076509
#  76        CJJG_KU_60  0.302901  0.037472
#  123    CJJG_PORE_TTM  0.278460  0.043969
#  138     CJJG_ROE_TTM  0.270584  0.079503
#  158       CJJG_TR_60  0.269259  0.051788,
#         features      mean       std
#  69     CJJG_ILQ  0.707832  0.089224
#  34      CJJG_DP  0.433727  0.132993
#  72  CJJG_ILQ_60  0.408452  0.100267
#  75  CJJG_KU_240  0.370045  0.065801,
#                  features      mean       std
#  97    CJJG_NCFOA_TTM_YOY  0.705652  0.060693
#  58       CJJG_ENIROA_TTM  0.510538  0.090284
#  35           CJJG_DP_TTM  0.475199  0.084696
#  134         CJJG_ROA_TTM  0.456852  0.079666
#  32      CJJG_DNP_TTM_YOY  0.315180  0.050983
#  121             CJJG_POG  0.307982  0.051226
#  112      CJJG_OP_TTM_YOY  0.258798  0.070121
#  69              CJJG_ILQ  0.249612  0.059176
#  106    CJJG_NPAT_TTM_YOY  0.248027  0.059613
#  15         CJJG_CCLR_TTM  0.245851  0.055745
#  72           CJJG_ILQ_60  0.244064  0.051184
#  52   CJJG_EBITDA_TTM_YOY  0.223226  0.042240
#  0               CJJG_ALR  0.211609  0.071905
#  62           CJJG_EP_TTM  0.197197  0.063185
#  28         CJJG_CTLR_TTM  0.194628  0.054027
#  123        CJJG_PORE_TTM  0.194509  0.041980
#  5           CJJG_ARR_TTM  0.187996  0.092272
#  158           CJJG_TR_60  0.180703  0.049687
#  19         CJJG_CNPR_TTM  0.170959  0.031015
#  157           CJJG_TR_20  0.159831  0.043146
#  117             CJJG_PCA  0.158540  0.041664
#  1            CJJG_ALR_AR  0.156530  0.051827
#  31          CJJG_DIO_TTM  0.152223  0.030496
#  77               CJJG_LR  0.151840  0.049945
#  3               CJJG_ARG  0.142871  0.029908
#  153           CJJG_SR_60  0.137513  0.036853
#  22       CJJG_CP_TTM_YOY  0.137195  0.028643
#  71           CJJG_ILQ_20  0.135163  0.035800
#  60       CJJG_ENIROE_TTM  0.122988  0.053671
#  34               CJJG_DP  0.119047  0.051285
#  110      CJJG_NP_TTM_YOY  0.118454  0.050618
#  70           CJJG_ILQ_10  0.116852  0.034293
#  136         CJJG_ROC_TTM  0.113837  0.032003
#  138         CJJG_ROE_TTM  0.111448  0.046825
#  13              CJJG_BTE  0.107084  0.027747
#  139             CJJG_RRG  0.103803  0.024663
#  125              CJJG_QR  0.102773  0.040574
#  154             CJJG_STM  0.102182  0.026142
#  56               CJJG_EG  0.101799  0.018653
#  98        CJJG_NCFOA_YOY  0.101657  0.033068
#  2              CJJG_ANPG  0.097209  0.021412
#  17           CJJG_CF_TTM  0.096343  0.035031
#  132            CJJG_RNPG  0.096067  0.015617,
#         features      mean       std
#  72  CJJG_ILQ_60  1.152238  0.059356
#  34      CJJG_DP  0.737648  0.149569,
#      features      mean       std
#  69  CJJG_ILQ  1.092366  0.075940
#  34   CJJG_DP  0.527081  0.127758,
#                 features      mean       std
#  69             CJJG_ILQ  0.441360  0.077007
#  118            CJJG_PFT  0.439496  0.069034
#  72          CJJG_ILQ_60  0.391942  0.035900
#  132           CJJG_RNPG  0.365246  0.049035
#  96         CJJG_MOM_240  0.281147  0.077487
#  70          CJJG_ILQ_10  0.197266  0.042904
#  11              CJJG_BI  0.165965  0.036357
#  158          CJJG_TR_60  0.135631  0.042538
#  79           CJJG_MA_10  0.132773  0.024476
#  122           CJJG_PORE  0.132404  0.031772
#  98       CJJG_NCFOA_YOY  0.129510  0.029367
#  2             CJJG_ANPG  0.125704  0.025771
#  90          CJJG_MDR_10  0.124415  0.031518
#  123       CJJG_PORE_TTM  0.122728  0.032113
#  88          CJJG_MDD_20  0.118212  0.030629
#  29             CJJG_CVP  0.117507  0.031284
#  121            CJJG_POG  0.115700  0.029463
#  75          CJJG_KU_240  0.114247  0.032242
#  139            CJJG_RRG  0.113712  0.029976
#  34              CJJG_DP  0.112484  0.023975
#  148          CJJG_SK_60  0.112398  0.021285
#  94          CJJG_MIR_20  0.111852  0.029413
#  7       CJJG_ATPROE_TTM  0.109502  0.038648
#  162         CJJG_VOL_60  0.109484  0.035301
#  76           CJJG_KU_60  0.107847  0.024592
#  161        CJJG_VOL_240  0.106571  0.034625
#  71          CJJG_ILQ_20  0.105516  0.031350
#  117            CJJG_PCA  0.105410  0.028446
#  159         CJJG_VOL_10  0.102702  0.025721
#  97   CJJG_NCFOA_TTM_YOY  0.102105  0.023516
#  120        CJJG_POE_TTM  0.101568  0.019667
#  3              CJJG_ARG  0.098480  0.031030
#  130         CJJG_REV_20  0.097846  0.023261
#  60      CJJG_ENIROE_TTM  0.095466  0.037017
#  9          CJJG_BETA_20  0.093775  0.025977
#  151          CJJG_SR_10  0.093637  0.018714,
#             features      mean       std
#  98   CJJG_NCFOA_YOY  0.129894  0.082402
#  138    CJJG_ROE_TTM  0.060815  0.075895
#  69         CJJG_ILQ  0.056073  0.093324
#  84      CJJG_MCI_10  0.050541  0.072853
#  163         CJJG_WC  0.050389  0.072588
#  ..              ...       ...       ...
#  88      CJJG_MDD_20  0.000000  0.000000
#  87      CJJG_MDD_10  0.000000  0.000000
#  86      CJJG_MCI_60  0.000000  0.000000
#  85      CJJG_MCI_20  0.000000  0.000000
#  82        CJJG_MBPM  0.000000  0.000000
#
#  [165 rows x 3 columns],
#           features      mean       std
#  92    CJJG_MDR_60  0.997437  0.052139
#  69       CJJG_ILQ  0.426139  0.033555
#  161  CJJG_VOL_240  0.289627  0.032720
#  35    CJJG_DP_TTM  0.223462  0.035407
#  34        CJJG_DP  0.198704  0.042398
#  72    CJJG_ILQ_60  0.174042  0.017462,
#            features      mean       std
#  118       CJJG_PFT  0.409737  0.056178
#  69        CJJG_ILQ  0.346929  0.032499
#  2        CJJG_ANPG  0.325400  0.042686
#  107  CJJG_NPAT_YOY  0.281645  0.087092
#  158     CJJG_TR_60  0.205705  0.032086
#  ..             ...       ...       ...
#  151     CJJG_SR_10  0.059254  0.014523
#  92     CJJG_MDR_60  0.058907  0.018781
#  113    CJJG_OP_YOY  0.058887  0.030271
#  155       CJJG_STR  0.058652  0.018125
#  19   CJJG_CNPR_TTM  0.058056  0.013478
#
#  [83 rows x 3 columns]]

# %%
feature_counter=Counter()   #特征出现次数
for DP80_feature in DP80_features_list:
    stock_names=set(DP80_feature['features'])
    feature_counter.update(DP80_feature['features']) #计数
    
#字典转换为Dataframe
stock_frequency_df=pd.DataFrame(feature_counter.items(),columns=['name','frequency'])

#按出现次数降序
stock_frequency_df=stock_frequency_df.sort_values(by=['frequency','name'],ascending=[False,True])
stock_frequency_df
# Out:
#                name  frequency
# 1           CJJG_DP         22
# 3          CJJG_ILQ         16
# 4       CJJG_ILQ_60         16
# 6       CJJG_DP_TTM         11
# 8   CJJG_ENIROE_TTM         11
# ..              ...        ...
# 81      CJJG_SK_240          1
# 82       CJJG_SR_20          1
# 87       CJJG_TR_10          1
# 66      CJJG_VOL_10          1
# 90          CJJG_WC          1
#
# [111 rows x 2 columns]

# %%
#替换特征名字，如果找不到映射，使用原名字
mapping_features=[mapping_dict.get(feature) for feature in stock_frequency_df['name'][:15]]

# %%
plt.barh(mapping_features,stock_frequency_df['frequency'][:15])
plt.xlabel('Frequency',fontsize=14)
plt.ylabel('Features',fontsize=14)
# plt.gca().set_xticks(range(0,20,2))
plt.gca().invert_yaxis()
plt.tight_layout()
# plt.savefig(f'data/fund/fig/DP80_feature.svg')
# plt.close()

# %% [markdown]
# ### 根据得到的SHAP值列表筛选特征，并画出频率图

# %%
#feature筛选方案
#所有基金的top5特征列表
top5_features_list=[]

#覆盖率80%重要性的特征列表
coverage80_features_list=[]

#DP特征指标80%以上卡阈值的特征列表
DP80_features_list=[]

#全部均值
importance_summary_list=[]
for fund_name in fund_names:
    base_dir=f'data/fund/model/{fund_name}'
    feature_file_names=[f'{base_dir}/xgb_{fund_name}_feature_importance{i}.csv' for i in range(30)]
    
    importance_features = []     
    for file in feature_file_names:
        df=pd.read_csv(file)
        importance_features.append(df)
        
    #横向拼接所有数据
    importance_all=pd.concat(importance_features)
    
    #按特征分组，计算特征重要性平均值，并排序
    importance_summary=(importance_all.groupby('features')['shap_values'].agg(['mean','std']).reset_index().sort_values(by='mean',ascending=False))
    
    #基于SHAP平均值选择top5的特征
    top5_features=importance_summary.head(5)
    
    #选择SHAP值覆盖总重要性的80%的特征
    total_shap=importance_summary['mean'].sum()
    importance_summary['shap_cumsum']=importance_summary['mean'].cumsum()
    shap_80_percent_coverage=importance_summary[importance_summary['shap_cumsum']<=0.8*total_shap]
    
    #选择DP特征重要性大于80%的特征
    dp_threshold=importance_summary[importance_summary['features']=='CJJG_DP']['mean']*0.8
    DP80_features=importance_summary[importance_summary['mean'].values>=dp_threshold.values]
    
    DP80_features_list.append(DP80_features)
    
    coverage80_features_list.append(shap_80_percent_coverage)
    
    top5_features_list.append(top5_features)
    
    importance_summary_list.append(importance_summary)

# %%
#选择需要展示的特征列表
features_list=coverage80_features_list

# %%
feature_counter=Counter()   #特征出现次数
for feature in features_list:
    stock_names=set(feature['features'])
    feature_counter.update(feature['features']) #计数
    
#字典转换为Dataframe
stock_frequency_df=pd.DataFrame(feature_counter.items(),columns=['name','frequency'])

#按出现次数降序
stock_frequency_df=stock_frequency_df.sort_values(by=['frequency','name'],ascending=[False,True])
stock_frequency_df
# Out:
#                 name  frequency
# 30          CJJG_ILQ         25
# 21       CJJG_ILQ_10         24
# 10          CJJG_POG         24
# 17         CJJG_RNPG         24
# 16        CJJG_TR_60         24
# ..               ...        ...
# 153         CJJG_GPM          1
# 156         CJJG_NPM          1
# 157      CJJG_NP_YOY          1
# 154  CJJG_RES_VOL_20          1
# 151          CJJG_SP          1
#
# [158 rows x 2 columns]

# %%
topshow=15
#替换特征名字，如果找不到映射，使用原名字
mapping_features=[mapping_dict.get(feature) for feature in stock_frequency_df['name'][:topshow]]

# %%
plt.barh(mapping_features,stock_frequency_df['frequency'][:topshow])
plt.xlabel('Frequency',fontsize=14)
plt.ylabel('Features',fontsize=14)
# plt.gca().set_xticks(range(0,21,3))
plt.gca().invert_yaxis()
plt.tight_layout()
# plt.savefig(f'data/fund/fig/TOP5_feature.svg')
plt.savefig(f'data/fund/fig/Coverage80_feature.svg')
# plt.savefig(f'data/fund/fig/DP80_feature.svg')
plt.close()

# %%
#横向拼接所有数据
importance_all_list=pd.concat(importance_summary_list)

# #按特征分组，计算特征重要性平均值，并排序
summary_all=(importance_all_list.groupby('features')['mean'].agg(['mean','std']).reset_index().sort_values(by='mean',ascending=False))

# %%
summary_all
# Out:
#                   features      mean       std
# 69                CJJG_ILQ  0.500944  0.466567
# 72             CJJG_ILQ_60  0.376744  0.314330
# 34                 CJJG_DP  0.296860  0.281015
# 35             CJJG_DP_TTM  0.284596  0.315889
# 96            CJJG_MOM_240  0.167193  0.114735
# ..                     ...       ...       ...
# 99          CJJG_NOPLAT2EV  0.000000  0.000000
# 100      CJJG_NOPLAT2EV_12  0.000000  0.000000
# 101  CJJG_NOPLAT2EV_12_TTM  0.000000  0.000000
# 104    CJJG_NOPLAT_TTM_YOY  0.000000  0.000000
# 105        CJJG_NOPLAT_YOY  0.000000  0.000000
#
# [165 rows x 3 columns]

# %%
#替换特征名字，如果找不到映射，使用原名字
mapping_features=[mapping_dict.get(feature) for feature in summary_all['features'][:15]]
mapping_features
# Out:
# ['非流动性',
#  '非流动性_60',
#  'DP',
#  'DP_TTM',
#  '动量_240',
#  '换手率_60',
#  '扣非ROE_TTM',
#  '波动率_240',
#  '盈利',
#  '最大跌幅_60',
#  '经营活动现金流净额_TTM_同比',
#  '相对营收增长',
#  '峰度_240',
#  '非流动性_10',
#  '空头意愿']

# %%
plt.barh(mapping_features,summary_all['mean'][:15])
plt.xlabel('Importance(Mean)',fontsize=14)
plt.ylabel('Feature',fontsize=14)
plt.gca().invert_yaxis()
plt.tight_layout()

# %% [markdown]
# ### DP的SHAP值为0的样本分析

# %%
#DP的SHAP值为0：004098.OF({0: 8701, 1: 3}),563180.OF({0: 4362, 1: 10}),007178.OF({0: 2974, 1: 2}),007216.OF({0: 2974, 1: 2})
#DP的SHAP值小于0.1：015290.OF({0: 12878, 1: 19})，015289.OF({0: 12878, 1: 19})，009188.OF({0.0: 30744, 1.0: 516})

# %%
print(tmp)
# Out:
# ['005770.OF', 34    0.625474
# Name: mean, dtype: float64, '004404.OF', 34    0.275778
# Name: mean, dtype: float64, '004098.OF', 34    0.0
# Name: mean, dtype: float64, '015290.OF', 34    0.00611
# Name: mean, dtype: float64, '006124.OF', 34    0.340362
# Name: mean, dtype: float64, '004403.OF', 34    0.297095
# Name: mean, dtype: float64, '008705.OF', 34    0.183963
# Name: mean, dtype: float64, '008737.OF', 34    0.516697
# Name: mean, dtype: float64, '501308.OF', 34    0.981867
# Name: mean, dtype: float64, '512590.OF', 34    0.449936
# Name: mean, dtype: float64, '563180.OF', 34    0.0
# Name: mean, dtype: float64, '009501.OF', 34    0.443973
# Name: mean, dtype: float64, '515690.OF', 34    0.244492
# Name: mean, dtype: float64, '008480.OF', 34    0.144996
# Name: mean, dtype: float64, '008481.OF', 34    0.146987
# Name: mean, dtype: float64, '004868.OF', 34    0.147013
# Name: mean, dtype: float64, '501307.OF', 34    0.973809
# Name: mean, dtype: float64, '007178.OF', 34    0.0
# Name: mean, dtype: float64, '015289.OF', 34    0.001957
# Name: mean, dtype: float64, '006123.OF', 34    0.331827
# Name: mean, dtype: float64, '009500.OF', 34    0.433727
# Name: mean, dtype: float64, '003702.OF', 34    0.119047
# Name: mean, dtype: float64, '000916.OF', 34    0.737648
# Name: mean, dtype: float64, '008736.OF', 34    0.527081
# Name: mean, dtype: float64, '008177.OF', 34    0.112484
# Name: mean, dtype: float64, '007216.OF', 34    0.0
# Name: mean, dtype: float64, '008704.OF', 34    0.198704
# Name: mean, dtype: float64, '009188.OF', 34    0.071064
# Name: mean, dtype: float64]

# %%
print(tmp1)
# Out:
# ['005770.OF', 14.383469523520002, '004404.OF', 13.461386542196667, '004098.OF', 1.9866943612000003, '015290.OF', 8.362932117513333, '006124.OF', 13.105480259845665, '004403.OF', 13.432690968643332, '008705.OF', 10.737664209126667, '008737.OF', 13.052217947253332, '501308.OF', 13.320632012291334, '512590.OF', 12.922877867566669, '563180.OF', 2.2229281115333333, '009501.OF', 11.630492810058, '515690.OF', 11.237521803263332, '008480.OF', 12.366531657443332, '008481.OF', 12.379775168843333, '004868.OF', 12.718112172316667, '501307.OF', 13.272719339837668, '007178.OF', 1.2600624026666667, '015289.OF', 8.385942741183335, '006123.OF', 13.069156195746665, '009500.OF', 11.594483016783332, '003702.OF', 13.932711312235334, '000916.OF', 12.065207554233334, '008736.OF', 13.072720748411, '008177.OF', 11.633733328828999, '007216.OF', 1.275302661, '008704.OF', 10.767479624243332, '009188.OF', 11.805738226416667]

# %%
#读取基金名称和月份数据，合并并清理空值，将每行的基金名称和其对应的非空月份分别存入两个列表
def clean_and_split_months(fund_names_path,months_path):
    #读取数据
    months_df=pd.read_csv(fund_names_path)
    fund_names_df=pd.read_csv(months_path)
    #合并数据框
    months_with_fund=pd.concat([fund_names_df,months_df],axis=1)
    #清理空值并将每一行的非空值提取为列表
    result_cleaned = months_with_fund.apply(lambda row: row.dropna().tolist(), axis=1)
    #分离基金名称和其对应的非空月份
    res = []
    for x in result_cleaned:
        if len(x) > 1:   #确保至少有基金名称和至少一个月份
            res.append(x)
    fund_names = [sublist[0] for sublist in res]
    months_list = [sublist[1:] for sublist in res]

    return fund_names,months_list

# %%
fund_names_path='data/fund/eda/months_df.csv'
months_path='data/fund/eda/fund_names_df.csv'
fund_names,months_list=clean_and_split_months(fund_names_path,months_path)

# %%
#005770.OF
fund_name='009188.OF'

# %%
all_data = []  # 存储所有月份的数据
for month in months_list[fund_names.index(fund_name)]:
    month=int(month)
    df = pd.read_csv(f'data/fund/eda/{fund_name}_eda_{month}.csv')
    df['month'] = month
    all_data.append(df)

# %%
data = pd.concat(all_data, ignore_index=True)
print(f'{fund_name}的eda数据shape是{data.shape}')
# Out:
# 009188.OF的eda数据shape是(31260, 168)

# %%
y = data['label']
print(f'{fund_name}的y数据shape是{y.shape}')
# 统计当前类别占比情况
print(f"基金{fund_name}在Before undersampling:{Counter(y)}")
# Out:
# 009188.OF的y数据shape是(31260,)
# 基金009188.OF在Before undersampling:Counter({0.0: 30744, 1.0: 516})

# %%
Counter(y)[1]/Counter(y)[0]>0.005
# Out:
# True

# %%
data['CJJG_DP'].describe()
# Out:
# count    30965.000000
# mean         0.011321
# std          0.015129
# min          0.000000
# 25%          0.000418
# 50%          0.006495
# 75%          0.015570
# max          0.411585
# Name: CJJG_DP, dtype: float64

# %%
sum(data['CJJG_DP']==0)
# Out:
# 7664

# %%
#直方图分布
sns.displot(data,x='CJJG_DP')

# %%
#直方图分布
sns.displot(data[data['label']==1],x='CJJG_DP')

# %%
sns.displot(data[data['label']==0],x='CJJG_DP')

# %%
#计算相关系数
#Pearson相关系数，用于衡量两个连续变量之间的线性相关性
correlation_matrix=data.corr()

# #上三角掩码
# mask=np.triu(np.ones_like(correlation_matrix,dtype=bool))
# np.fill_diagonal(mask,False)

# #绘制热力图
# sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt='.2f',linewidth=0.5,mask=mask)

# %%
correlation_matrix['CJJG_DP'].sort_values(ascending=False)
# Out:
# CJJG_DP            1.000000
# CJJG_DP_TTM        0.987681
# CJJG_EP_TTM        0.444788
# CJJG_BP            0.390534
# CJJG_EP            0.344764
#                      ...
# CJJG_RV           -0.202605
# CJJG_MIR_60       -0.223267
# CJJG_VOL_60       -0.236014
# CJJG_RES_VOL_60   -0.240550
# CJJG_VOL_240      -0.321364
# Name: CJJG_DP, Length: 167, dtype: float64

# %%
#计算斯皮尔曼相关系数，衡量两个变量之间的等级关系的强度和方向，不要求变量之间的关系是线性的
correlation_matrix=data.corr(method='spearman')

# %%
correlation_matrix['CJJG_DP'].sort_values(ascending=False)
# Out:
# CJJG_DP                  1.000000
# CJJG_DP_TTM              0.998987
# CJJG_EP_TTM              0.680563
# CJJG_EBIT2EV_12_TTM      0.640962
# CJJG_NOPLAT2EV_12_TTM    0.640962
#                            ...
# CJJG_MA_60              -0.319256
# CJJG_RES_VOL_60         -0.364670
# CJJG_VOL_60             -0.369889
# CJJG_VOL_240            -0.445027
# month                         NaN
# Name: CJJG_DP, Length: 167, dtype: float64

# %% [markdown]
# ### 收益率计算

# %%
# 获取高股息的基金代码，S_INFO_OUTERCODE：基金场外代码，F_INFO_FULLNAME：基金名称
connection = cx_Oracle.connect('wind', 'wind', '10.6.60.114:1521/wind')
cursor = connection.cursor()
sql = "select S_INFO_OUTERCODE,F_INFO_NAME,F_INFO_CORP_FUNDMANAGEMENTCOMP from ChinaMutualFundDescription where F_INFO_FULLNAME like '%股息%'"
print('从数据库中获取高股息基金数据: ' + sql)
cursor.execute(sql)
columns = [col[0] for col in cursor.description]
results = cursor.fetchall()
df1 = pd.DataFrame(results, columns=columns)
print(df1)
cursor.close()
connection.close()
# Out:
# 从数据库中获取高股息基金数据: select S_INFO_OUTERCODE,F_INFO_NAME,F_INFO_CORP_FUNDMANAGEMENTCOMP from ChinaMutualFundDescription where F_INFO_FULLNAME like '%股息%'
#    S_INFO_OUTERCODE        F_INFO_NAME F_INFO_CORP_FUNDMANAGEMENTCOMP
# 0         005770.OF           信澳沪港深高股息                         信达澳亚基金
# 1         004404.OF            平安股息精选C                           平安基金
# 2         004098.OF         前海开源股息率50强                         前海开源基金
# 3         015290.OF           格林高股息优选C                           格林基金
# 4         006124.OF           国联高股息精选C                           国联基金
# ..              ...                ...                            ...
# 61        022073.OF    天弘中证港股通高股息投资指数C                           天弘基金
# 62        022274.OF    国泰中证港股通高股息投资联接A                           国泰基金
# 63        022145.OF       银华中证高股息策略联接C                           银华基金
# 64        022144.OF       银华中证高股息策略联接A                           银华基金
# 65        022663.OF  华泰柏瑞中证港股通高股息投资联接I                         华泰柏瑞基金
#
# [66 rows x 3 columns]

# %%
# 获取高股息的基金经理信息，MANAGERNAME：基金经理名称，COMPNAME：基金公司名称，FDSNAME：基金简称，BEGINDATE：就职日期,ENDDATE：离职日期，ALLAVGYIELD：整体平均收益率
connection = cx_Oracle.connect('finchina', 'finchina', '10.6.60.118:1521/orcl')
cursor = connection.cursor()
sql = "SELECT MANAGERNAME,COMPNAME,FDSNAME,BEGINDATE,ENDDATE,ALLAVGYIELD FROM TQ_FD_MGPERFORMANCE where FDSNAME like '%股息%'"
print('从数据库中获取高股息基金数据: ' + sql)
cursor.execute(sql)
columns = [col[0] for col in cursor.description]
results = cursor.fetchall()
df2 = pd.DataFrame(results, columns=columns)
print(df2)
cursor.close()
connection.close()
# Out:
# 从数据库中获取高股息基金数据: SELECT MANAGERNAME,COMPNAME,FDSNAME,BEGINDATE,ENDDATE,ALLAVGYIELD FROM TQ_FD_MGPERFORMANCE where FDSNAME like '%股息%'
#     MANAGERNAME       COMPNAME                   FDSNAME BEGINDATE   ENDDATE  \
# 0            丁尧   前海开源基金管理有限公司            前海开源股息率100强股票A  20200909  20210422
# 1            冯琪     国联基金管理有限公司                  国联高股息混合A  20200622  20211122
# 2            冯琪     国联基金管理有限公司                  国联高股息混合C  20200622  20211122
# 3            刘威   信达澳亚基金管理有限公司            信澳中证沪港深高股息精选指数  20200415  20211117
# 4            晏青     永赢基金管理有限公司                   永赢股息优选A  20200325  20231017
# ..          ...            ...                       ...       ...       ...
# 162         吴可凡     国泰基金管理有限公司      国泰中证港股通高股息投资ETF发起联接A  20241009  19000101
# 163         吴可凡     国泰基金管理有限公司      国泰中证港股通高股息投资ETF发起联接C  20241009  19000101
# 164          朱丹     国泰基金管理有限公司      国泰中证港股通高股息投资ETF发起联接A  20241009  19000101
# 165          晏阳  汇添富基金管理股份有限公司  汇添富中证港股通高股息投资ETF联接(LOF)A  20230413  19000101
# 166          李茜   华泰柏瑞基金管理有限公司   华泰柏瑞中证港股通高股息投资ETF发起式联接I  20241126  19000101
#
#      ALLAVGYIELD
# 0         8.2992
# 1        23.9221
# 2        23.9092
# 3        32.0848
# 4        16.6724
# ..           ...
# 162       0.8175
# 163       0.8175
# 164       0.8175
# 165      -2.3591
# 166       1.5730
#
# [167 rows x 6 columns]

# %%
fund_names
# Out:
# ['005770.OF',
#  '004404.OF',
#  '004098.OF',
#  '015290.OF',
#  '006124.OF',
#  '004403.OF',
#  '008705.OF',
#  '008737.OF',
#  '501308.OF',
#  '512590.OF',
#  '563180.OF',
#  '009501.OF',
#  '515690.OF',
#  '008480.OF',
#  '008481.OF',
#  '004868.OF',
#  '501307.OF',
#  '007178.OF',
#  '015289.OF',
#  '006123.OF',
#  '009500.OF',
#  '003702.OF',
#  '000916.OF',
#  '008736.OF',
#  '008177.OF',
#  '007216.OF',
#  '008704.OF',
#  '009188.OF']

# %%
fund_info=df1[df1['S_INFO_OUTERCODE'].isin(fund_names)]

# %%
FUNDMANAGEMENTCOMP=df1[df1['S_INFO_OUTERCODE'].isin(fund_names)]['F_INFO_CORP_FUNDMANAGEMENTCOMP']
FUNDMANAGEMENTCOMP
# Out:
# 0      信达澳亚基金
# 1        平安基金
# 2      前海开源基金
# 3        格林基金
# 4        国联基金
# 7        平安基金
# 8        广发基金
# 10       南方基金
# 13       银河基金
# 16     浦银安盛基金
# 17       银华基金
# 24     国寿安保基金
# 25       鹏华基金
# 26       永赢基金
# 28       永赢基金
# 29    交银施罗德基金
# 39       银河基金
# 41       浙商基金
# 42       格林基金
# 43       国联基金
# 44     国寿安保基金
# 45       平安基金
# 46     前海开源基金
# 49       南方基金
# 51       建信基金
# 54       浙商基金
# 55       广发基金
# 57       鹏华基金
# Name: F_INFO_CORP_FUNDMANAGEMENTCOMP, dtype: object

# %%
df2.columns
# Out:
# Index(['MANAGERNAME', 'COMPNAME', 'FDSNAME', 'BEGINDATE', 'ENDDATE',
#        'ALLAVGYIELD'],
#       dtype='object')

# %%
filtered_df=df2[df2['COMPNAME'].str[:4].isin([name[:4] for name in FUNDMANAGEMENTCOMP])]

# %%
filtered_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 filtered_df
#
# NameError: name 'filtered_df' is not defined

# %%
filtered_df[filtered_df['COMPNAME'].str.contains('平安基金')]
#201712-202406---78      #43,17,27,29,78   43/78*5.498+17/78*20.54+27/78*19.487+29/78*12.056
#43,17,27,29 43/78*5.498+17/78*20.54+27/78*19.487+29/78*12.056
#33，28，36 33/36*13.439+28/36*23.24
#(42/78)*5.49+()
# Out:
#     MANAGERNAME    COMPNAME       FDSNAME BEGINDATE   ENDDATE  ALLAVGYIELD
# 22           成钧  平安基金管理有限公司  平安股息精选沪港深股票A  20200624  20240103       5.4958
# 23          毛时超  平安基金管理有限公司  平安股息精选沪港深股票A  20200624  20211105      20.5401
# 24           成钧  平安基金管理有限公司  平安股息精选沪港深股票C  20200624  20240103       5.4981
# 25          毛时超  平安基金管理有限公司  平安股息精选沪港深股票C  20200624  20211105      20.5401
# 69           施旭  平安基金管理有限公司  平安中证沪港深高股息指数  20170125  20191021      13.4390
# 70           钱晶  平安基金管理有限公司  平安中证沪港深高股息指数  20180326  20200702      23.2403
# 76          孙东宁  平安基金管理有限公司  平安股息精选沪港深股票A  20180307  20200629      19.5140
# 77           施旭  平安基金管理有限公司  平安股息精选沪港深股票A  20170517  20191021      12.0570
# 78          孙东宁  平安基金管理有限公司  平安股息精选沪港深股票C  20180307  20200629      19.4870
# 79           施旭  平安基金管理有限公司  平安股息精选沪港深股票C  20170517  20191021      12.0565
# 98           刘杰  平安基金管理有限公司  平安股息精选沪港深股票A  20220610  19000101      -1.3208
# 103          俞瑶  平安基金管理有限公司  平安股息精选沪港深股票A  20211104  20230725      -8.7272
# 104          俞瑶  平安基金管理有限公司  平安股息精选沪港深股票C  20211104  20230725      -8.7264
# 115          刘杰  平安基金管理有限公司  平安股息精选沪港深股票C  20220610  19000101      -1.3208

# %%
result=(33/36*13.439)+(28/36*23.24)
result
# Out:
# 30.394638888888885

# %%
tmp=filtered_df[filtered_df['COMPNAME'].str.contains('平安基金')]
# tmp['BEGINDATE']

# %%
from datetime import datetime
date1=tmp['BEGINDATE'][70]
date2=tmp['ENDDATE'][70]
# date1='20170601'
# date2='20200601'
d1=datetime.strptime(date1,'%Y%m%d')
d2=datetime.strptime(date2,'%Y%m%d')
months_diff=(d2.year-d1.year)*12+(d2.month-d1.month)
months_diff
# Out:
# 36

# %%
fund_info[fund_info['F_INFO_CORP_FUNDMANAGEMENTCOMP']=='建信基金']
# Out:
#    S_INFO_OUTERCODE F_INFO_NAME F_INFO_CORP_FUNDMANAGEMENTCOMP  ALLAVGYIELD  \
# 51        008177.OF     建信高股息主题                           建信基金          0.0
#
#     START_DATE  LAST_DATE
# 51    202006.0   202406.0

# %%
fund_info
# Out:
#    S_INFO_OUTERCODE   F_INFO_NAME F_INFO_CORP_FUNDMANAGEMENTCOMP  ALLAVGYIELD
# 0         005770.OF      信澳沪港深高股息                         信达澳亚基金        35.73
# 1         004404.OF       平安股息精选C                           平安基金        18.74
# 4         006124.OF      国联高股息精选C                           国联基金        22.67
# 7         004403.OF       平安股息精选A                           平安基金        18.73
# 8         008705.OF      广发高股息优享C                           广发基金         9.33
# 10        008737.OF      南方高股息主题C                           南方基金         6.68
# 13        501308.OF   银河中证沪港深高股息C                           银河基金         3.99
# 16        512590.OF        高股息ETF                         浦银安盛基金        41.00
# 24        009501.OF      国寿安保高股息C                         国寿安保基金         1.13
# 25        515690.OF         股息ETF                           鹏华基金        30.00
# 26        008480.OF       永赢股息优选A                           永赢基金        12.67
# 28        008481.OF       永赢股息优选C                           永赢基金        12.67
# 29        004868.OF        交银股息优化                        交银施罗德基金        41.16
# 39        501307.OF      沪港深红利LOF                           银河基金         5.71
# 43        006123.OF      国联高股息精选A                           国联基金         9.86
# 44        009500.OF      国寿安保高股息A                         国寿安保基金         5.70
# 45        003702.OF      平安沪港深高股息                           平安基金        18.15
# 46        000916.OF  前海开源股息率100强A                         前海开源基金        22.30
# 49        008736.OF      南方高股息主题A                           南方基金         6.67
# 51        008177.OF       建信高股息主题                           建信基金        20.67
# 55        008704.OF      广发高股息优享A                           广发基金        12.75
# 57        009188.OF        鹏华股息精选                           鹏华基金         8.30

# %%
fund_info.loc[57,'ALLAVGYIELD']=8.3

# %%
fund_info
# Out:
#    S_INFO_OUTERCODE        F_INFO_NAME F_INFO_CORP_FUNDMANAGEMENTCOMP  \
# 0         005770.OF           信澳沪港深高股息                         信达澳亚基金
# 1         004404.OF            平安股息精选C                           平安基金
# 2         004098.OF         前海开源股息率50强                         前海开源基金
# 3         015290.OF           格林高股息优选C                           格林基金
# 4         006124.OF           国联高股息精选C                           国联基金
# 7         004403.OF            平安股息精选A                           平安基金
# 8         008705.OF           广发高股息优享C                           广发基金
# 10        008737.OF           南方高股息主题C                           南方基金
# 13        501308.OF        银河中证沪港深高股息C                           银河基金
# 16        512590.OF             高股息ETF                         浦银安盛基金
# 17        563180.OF             高股息ETF                           银华基金
# 24        009501.OF           国寿安保高股息C                         国寿安保基金
# 25        515690.OF              股息ETF                           鹏华基金
# 26        008480.OF            永赢股息优选A                           永赢基金
# 28        008481.OF            永赢股息优选C                           永赢基金
# 29        004868.OF             交银股息优化                        交银施罗德基金
# 39        501307.OF           沪港深红利LOF                           银河基金
# 41        007178.OF  浙商港股通中华预期高股息指数增强A                           浙商基金
# 42        015289.OF           格林高股息优选A                           格林基金
# 43        006123.OF           国联高股息精选A                           国联基金
# 44        009500.OF           国寿安保高股息A                         国寿安保基金
# 45        003702.OF           平安沪港深高股息                           平安基金
# 46        000916.OF       前海开源股息率100强A                         前海开源基金
# 49        008736.OF           南方高股息主题A                           南方基金
# 51        008177.OF            建信高股息主题                           建信基金
# 54        007216.OF  浙商港股通中华预期高股息指数增强C                           浙商基金
# 55        008704.OF           广发高股息优享A                           广发基金
# 57        009188.OF             鹏华股息精选                           鹏华基金
#
#     ALLAVGYIELD  START_DATE  LAST_DATE
# 0         35.73    201906.0   202212.0
# 1         18.74    201712.0   202406.0
# 2          9.10    202312.0   202406.0
# 3          0.39    202306.0   202406.0
# 4         22.67    201912.0   202406.0
# 7         18.73    201712.0   202406.0
# 8          9.33    202006.0   202406.0
# 10         6.68    202012.0   202406.0
# 13         3.99    201806.0   202406.0
# 16        41.00    201903.0   202212.0
# 17         5.97    202405.0   202405.0
# 24         1.13    202012.0   202406.0
# 25        30.00    202005.0   202106.0
# 26        12.67    202006.0   202406.0
# 28        12.67    202006.0   202406.0
# 29        41.16    201712.0   202406.0
# 39         5.71    201806.0   202406.0
# 41         0.00    202006.0   202006.0
# 42         0.39    202306.0   202406.0
# 43         9.86    201912.0   202406.0
# 44         5.70    202012.0   202406.0
# 45        18.15    201706.0   202006.0
# 46        22.30    201506.0   202406.0
# 49         6.67    202012.0   202406.0
# 51        20.67    202006.0   202406.0
# 54         0.00    202006.0   202006.0
# 55        12.75    202006.0   202406.0
# 57         8.30    202012.0   202406.0

# %% [markdown]
# ##### 浙商基金,银华基金 开始与结束日期相同

# %%
#DP的SHAP值小于0.1且正样本过少：004098.OF({0: 8701, 1: 3}),563180.OF({0: 4362, 1: 10}),007178.OF({0: 2974, 1: 2}),007216.OF({0: 2974, 1: 2})，015290.OF({0: 12878, 1: 19})，015289.OF({0: 12878, 1: 19})
remove_list=['004098.OF','563180.OF','007178.OF','007216.OF','015290.OF','015289.OF']
fund_filter_info=fund_info[~fund_info['S_INFO_OUTERCODE'].isin(remove_list)]

# %%
fund_filter_info
# Out:
#    S_INFO_OUTERCODE   F_INFO_NAME F_INFO_CORP_FUNDMANAGEMENTCOMP  ALLAVGYIELD  \
# 0         005770.OF      信澳沪港深高股息                         信达澳亚基金        35.73
# 1         004404.OF       平安股息精选C                           平安基金        18.74
# 4         006124.OF      国联高股息精选C                           国联基金        22.67
# 7         004403.OF       平安股息精选A                           平安基金        18.73
# 8         008705.OF      广发高股息优享C                           广发基金         9.33
# 10        008737.OF      南方高股息主题C                           南方基金         6.68
# 13        501308.OF   银河中证沪港深高股息C                           银河基金         3.99
# 16        512590.OF        高股息ETF                         浦银安盛基金        41.00
# 24        009501.OF      国寿安保高股息C                         国寿安保基金         1.13
# 25        515690.OF         股息ETF                           鹏华基金        30.00
# 26        008480.OF       永赢股息优选A                           永赢基金        12.67
# 28        008481.OF       永赢股息优选C                           永赢基金        12.67
# 29        004868.OF        交银股息优化                        交银施罗德基金        41.16
# 39        501307.OF      沪港深红利LOF                           银河基金         5.71
# 43        006123.OF      国联高股息精选A                           国联基金         9.86
# 44        009500.OF      国寿安保高股息A                         国寿安保基金         5.70
# 45        003702.OF      平安沪港深高股息                           平安基金        18.15
# 46        000916.OF  前海开源股息率100强A                         前海开源基金        22.30
# 49        008736.OF      南方高股息主题A                           南方基金         6.67
# 51        008177.OF       建信高股息主题                           建信基金        20.67
# 55        008704.OF      广发高股息优享A                           广发基金        12.75
# 57        009188.OF        鹏华股息精选                           鹏华基金         8.30
#
#     START_DATE  LAST_DATE
# 0     201906.0   202212.0
# 1     201712.0   202406.0
# 4     201912.0   202406.0
# 7     201712.0   202406.0
# 8     202006.0   202406.0
# 10    202012.0   202406.0
# 13    201806.0   202406.0
# 16    201903.0   202212.0
# 24    202012.0   202406.0
# 25    202005.0   202106.0
# 26    202006.0   202406.0
# 28    202006.0   202406.0
# 29    201712.0   202406.0
# 39    201806.0   202406.0
# 43    201912.0   202406.0
# 44    202012.0   202406.0
# 45    201706.0   202006.0
# 46    201506.0   202406.0
# 49    202012.0   202406.0
# 51    202006.0   202406.0
# 55    202006.0   202406.0
# 57    202012.0   202406.0

# %%
fund_filter_info=fund_info

# %%
fund_filter_info.to_csv(f'data/fund/analyze/fund_filter_info.csv', index=False)

# %% [markdown]
# ### 根据基金收益对SHAP进行加权

# %%
#feature筛选方案
#全部均值
importance_summary_list=[]
total_ALLAVGYIELD=sum(fund_filter_info['ALLAVGYIELD'])
for fund_name in fund_names:
    base_dir=f'data/fund/model/{fund_name}'
    feature_file_names=[f'{base_dir}/xgb_{fund_name}_feature_importance{i}.csv' for i in range(30)]
    
    importance_features = []     
    for file in feature_file_names:
        df=pd.read_csv(file)
        importance_features.append(df)
        
    #横向拼接所有数据
    importance_all=pd.concat(importance_features)
    
    #按特征分组，计算特征重要性平均值，并排序
    importance_summary=(importance_all.groupby('features')['shap_values'].agg(['mean','std']).reset_index().sort_values(by='mean',ascending=False))
    
    weight=(fund_filter_info[fund_filter_info['S_INFO_OUTERCODE']==fund_name]['ALLAVGYIELD'])/total_ALLAVGYIELD
    print(f'{fund_name}的权重为{weight.values[0]}')
    
    importance_summary['weight_shap']=importance_summary['mean']*weight.values[0]
    importance_summary_list.append(importance_summary)
# Out:
# 005770.OF的权重为0.09799511807136391
# 004404.OF的权重为0.05139738350566358
# 006124.OF的权重为0.062176023696552486
# 004403.OF的权重为0.051369956940292366
# 008705.OF的权重为0.025588985491346916
# 008737.OF的权重为0.018320945667973997
# 501308.OF的权重为0.010943199583116207
# 512590.OF的权重为0.1124489180219961
# 009501.OF的权重为0.003099201886947697
# 515690.OF的权重为0.08227969611365568
# 008480.OF的权重为0.034749458325333916
# 008481.OF的权重为0.034749458325333916
# 004868.OF的权重为0.11288774306793559
# 501307.OF的权重为0.015660568826965798
# 006123.OF的权重为0.0270425934560215
# 009500.OF的权重为0.015633142261594582
# 003702.OF的权重为0.049779216148761685
# 000916.OF的权重为0.06116124077781739
# 008736.OF的权重为0.01829351910260278
# 008177.OF的权重为0.05669071062230877
# 008704.OF的权重为0.03496887084830366
# 009188.OF的权重为0.02276404925811141

# %%
importance_summary
# Out:
#                   features      mean       std  weight_shap
# 118               CJJG_PFT  0.399412  0.056909     0.009092
# 69                CJJG_ILQ  0.354441  0.047739     0.008069
# 2                CJJG_ANPG  0.322223  0.043138     0.007335
# 107          CJJG_NPAT_YOY  0.309728  0.088188     0.007051
# 158             CJJG_TR_60  0.201425  0.036921     0.004585
# ..                     ...       ...       ...          ...
# 104    CJJG_NOPLAT_TTM_YOY  0.000000  0.000000     0.000000
# 100      CJJG_NOPLAT2EV_12  0.000000  0.000000     0.000000
# 105        CJJG_NOPLAT_YOY  0.000000  0.000000     0.000000
# 101  CJJG_NOPLAT2EV_12_TTM  0.000000  0.000000     0.000000
# 102     CJJG_NOPLAT2EV_TTM  0.000000  0.000000     0.000000
#
# [165 rows x 4 columns]

# %%
#横向拼接所有数据
importance_all_list=pd.concat(importance_summary_list)

# #按特征分组，计算特征重要性平均值，并排序
summary_all=(importance_all_list.groupby('features')['mean'].agg(['mean','std']).reset_index().sort_values(by='mean',ascending=False))

# %%
summary_all
# Out:
#                   features      mean       std
# 69                CJJG_ILQ  0.597712  0.465215
# 72             CJJG_ILQ_60  0.475569  0.286272
# 34                 CJJG_DP  0.384742  0.272572
# 35             CJJG_DP_TTM  0.352654  0.316253
# 158             CJJG_TR_60  0.198885  0.078097
# ..                     ...       ...       ...
# 104    CJJG_NOPLAT_TTM_YOY  0.000000  0.000000
# 99          CJJG_NOPLAT2EV  0.000000  0.000000
# 102     CJJG_NOPLAT2EV_TTM  0.000000  0.000000
# 101  CJJG_NOPLAT2EV_12_TTM  0.000000  0.000000
# 105        CJJG_NOPLAT_YOY  0.000000  0.000000
#
# [165 rows x 3 columns]

# %%
#替换特征名字，如果找不到映射，使用原名字
mapping_features=[mapping_dict.get(feature) for feature in summary_all['features'][:15]]
plt.barh(mapping_features,summary_all['mean'][:15])
plt.xlabel('Importance(Mean)',fontsize=14)
plt.ylabel('Feature',fontsize=14)
plt.gca().invert_yaxis()
plt.tight_layout()
# plt.savefig(f'data/fund/fig/Weighted_SHAP_feature.svg')
# plt.close()

# %%
list(summary_all['features'][:15])
# Out:
# ['CJJG_ILQ',
#  'CJJG_ILQ_60',
#  'CJJG_DP',
#  'CJJG_DP_TTM',
#  'CJJG_TR_60',
#  'CJJG_MOM_240',
#  'CJJG_ENIROE_TTM',
#  'CJJG_VOL_240',
#  'CJJG_PFT',
#  'CJJG_MDR_60',
#  'CJJG_KU_240',
#  'CJJG_NCFOA_TTM_YOY',
#  'CJJG_ILQ_10',
#  'CJJG_BI',
#  'CJJG_ILQ_20']

# %% [markdown]
# ### top5特征筛选，收益率高的一次加的数>1，收益率低的一次加的数<1

# %%
#所有基金的top5特征列表
top5_features_list=[]
for fund_name in fund_names:
    base_dir=f'data/fund/model/{fund_name}'
    feature_file_names=[f'{base_dir}/xgb_{fund_name}_feature_importance{i}.csv' for i in range(30)]
    
    importance_features = []     
    for file in feature_file_names:
        df=pd.read_csv(file)
        importance_features.append(df)
        
    #横向拼接所有数据
    importance_all=pd.concat(importance_features)
    
    #按特征分组，计算特征重要性平均值，并排序
    importance_summary=(importance_all.groupby('features')['shap_values'].agg(['mean','std']).reset_index().sort_values(by='mean',ascending=False))
    importance_summary['fund_name']=fund_name
    

    
   #基于SHAP平均值选择top5的特征
    top5_features=importance_summary[['features','fund_name']].head(5)

    
    top5_features_list.append(top5_features)
    
    # #替换特征名字，如果找不到映射，使用原名字
    # mapping_features=[mapping_dict.get(feature) for feature in top15_features['features']]

# %%
top5_features_list[0]
# Out:
#               features  fund_name
# 5         CJJG_ARR_TTM  005770.OF
# 34             CJJG_DP  005770.OF
# 97  CJJG_NCFOA_TTM_YOY  005770.OF
# 58     CJJG_ENIROA_TTM  005770.OF
# 3             CJJG_ARG  005770.OF

# %%
#计算得到收益中位数
profit_res=[]
for fund_name in fund_names:
    res=fund_filter_info[fund_filter_info['S_INFO_OUTERCODE']==fund_name]
    profit_res.append(res[['S_INFO_OUTERCODE','ALLAVGYIELD']])
all_profits=pd.concat([df['ALLAVGYIELD'] for df in profit_res])
global_median=all_profits.median()

# %%
global_median
# Out:
# 12.71

# %%
#添加label列，表明收益率高低
process_dataframes=[]
for df in profit_res:
    df['label']=df['ALLAVGYIELD'].apply(lambda x:'高收益率' if x>global_median else '低收益率')
    process_dataframes.append(df)

# %%
process_dataframe=pd.concat(df for df in process_dataframes)
process_dataframe
# Out:
#    S_INFO_OUTERCODE  ALLAVGYIELD label
# 0         005770.OF        35.73  高收益率
# 1         004404.OF        18.74  高收益率
# 4         006124.OF        22.67  高收益率
# 7         004403.OF        18.73  高收益率
# 8         008705.OF         9.33  低收益率
# 10        008737.OF         6.68  低收益率
# 13        501308.OF         3.99  低收益率
# 16        512590.OF        41.00  高收益率
# 24        009501.OF         1.13  低收益率
# 25        515690.OF        30.00  高收益率
# 26        008480.OF        12.67  低收益率
# 28        008481.OF        12.67  低收益率
# 29        004868.OF        41.16  高收益率
# 39        501307.OF         5.71  低收益率
# 43        006123.OF         9.86  低收益率
# 44        009500.OF         5.70  低收益率
# 45        003702.OF        18.15  高收益率
# 46        000916.OF        22.30  高收益率
# 49        008736.OF         6.67  低收益率
# 51        008177.OF        20.67  高收益率
# 55        008704.OF        12.75  高收益率
# 57        009188.OF         8.30  低收益率

# %%
#权重设置
weight_mapping={'高收益率':1.5,'低收益率':0.5}

#统计特征频率
feature_counts=Counter()

for df in top5_features_list:
    fund_name=df['fund_name'].iloc[0]  #获取当前基金名称
    if fund_name in process_dataframe['S_INFO_OUTERCODE'].values:
        label=process_dataframe.loc[process_dataframe['S_INFO_OUTERCODE']==fund_name,'label'].values[0]
        weight=weight_mapping.get(label,1)   #根据收益率标注获取权重
        for feature in df['features']:
            feature_counts[feature]+=weight

# %%
#字典转换为Dataframe
stock_frequency_df=pd.DataFrame(feature_counts.items(),columns=['name','frequency'])

#按出现次数降序
stock_frequency_df=stock_frequency_df.sort_values(by='frequency',ascending=False)
stock_frequency_df
# Out:
#                   name  frequency
# 5             CJJG_ILQ       13.5
# 6          CJJG_ILQ_60       13.0
# 1              CJJG_DP       11.5
# 8          CJJG_DP_TTM       11.0
# 9         CJJG_MOM_240        6.5
# 7         CJJG_VOL_240        6.5
# 13            CJJG_PFT        4.5
# 2   CJJG_NCFOA_TTM_YOY        4.5
# 3      CJJG_ENIROA_TTM        4.5
# 19          CJJG_TR_60        3.5
# 18         CJJG_KU_240        3.5
# 17        CJJG_ROA_TTM        3.0
# 10     CJJG_ENIROE_TTM        3.0
# 11          CJJG_KU_60        2.0
# 12         CJJG_MDR_60        2.0
# 25         CJJG_ILQ_20        1.5
# 20         CJJG_MIR_60        1.5
# 22       CJJG_PORE_TTM        1.5
# 0         CJJG_ARR_TTM        1.5
# 16             CJJG_LR        1.5
# 26           CJJG_RNPG        1.5
# 24            CJJG_POG        1.5
# 4             CJJG_ARG        1.5
# 23            CJJG_RRG        1.5
# 14  CJJG_EBITDA2EV_TTM        1.0
# 21            CJJG_DSO        1.0
# 15         CJJG_ILQ_10        1.0
# 27           CJJG_ANPG        0.5
# 28       CJJG_NPAT_YOY        0.5

# %%
#替换特征名字，如果找不到映射，使用原名字
mapping_features=[mapping_dict.get(feature) for feature in stock_frequency_df['name'][:15]]

# %%
mapping_features
# Out:
# ['非流动性',
#  '非流动性_60',
#  'DP',
#  'DP_TTM',
#  '动量_240',
#  '波动率_240',
#  '盈利',
#  '经营活动现金流净额_TTM_同比',
#  '扣非ROA_TTM',
#  '换手率_60',
#  '峰度_240',
#  'ROA_TTM',
#  '扣非ROE_TTM',
#  '峰度_60',
#  '最大跌幅_60']

# %%
plt.barh(mapping_features,stock_frequency_df['frequency'][:15])
plt.xlabel('Frequency',fontsize=14)
plt.ylabel('Features',fontsize=14)
# plt.gca().set_xticks(range(0,20,2))
plt.gca().invert_yaxis()
plt.tight_layout()
# plt.savefig(f'data/fund/fig/Weighted_SHAP_feature_Top5.svg')
# plt.close()
